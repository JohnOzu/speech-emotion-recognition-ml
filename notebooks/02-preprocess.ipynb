# %% [markdown]
# # Import Libraries

# %%
import os
import importlib
import sys
from tqdm import tqdm
import pandas as pd

# %% [markdown]
# # Import Utils

# %%
sys.path.append("..")
import utils
from utils import process_file

importlib.reload(utils)

from utils import process_file

# %% [markdown]
# # Set directories

# %%
RAW_DIR = "../data/raw"
OUTPUT_DIR = "../data/processed/audio_16k"
TARGET_SR = 16000
TARGET_DURATION = 3.0
TARGET_LENGTH = int(TARGET_SR * TARGET_DURATION)

os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# # Process datasets

# %%
rows = []

for dataset in os.listdir(RAW_DIR):
    dataset_path = os.path.join(RAW_DIR, dataset)
    if not os.path.isdir(dataset_path):
        continue
    
    for file in tqdm(os.listdir(dataset_path), desc=f"Processing {dataset}"):
        if file.lower().endswith((".wav", ".mp3", ".flac", ".ogg")):
            process_file(os.path.join(dataset_path, file), rows)
# Out:
# Processing tess: 100%|█████████████████████████████████████████████████████████████| 2357/2357 [00:08<00:00, 286.12it/s]
# Processing savee: 100%|██████████████████████████████████████████████████████████████| 480/480 [00:01<00:00, 351.89it/s]
# Processing .ipynb_checkpoints: 0it [00:00, ?it/s]
# Processing ravdess: 100%|██████████████████████████████████████████████████████████| 1248/1248 [00:03<00:00, 355.83it/s]
# Processing crema-d: 100%|██████████████████████████████████████████████████████████| 3901/3901 [00:06<00:00, 561.62it/s]

# %% [markdown]
# # Save metadata.csv

# %%
df = pd.DataFrame(rows, columns=["file_path","emotion","dataset","actor", "index","sample_rate"])
df.to_csv("../data/processed/metadata.csv", index=False)
df.head()
# Out:
#                                            file_path  emotion dataset actor  \
# 0  ../data/processed/audio_16k/savee_YAF_sad_1630...      sad   savee   YAF
# 1  ../data/processed/audio_16k/savee_YAF_fear_186...     fear   savee   YAF
# 2  ../data/processed/audio_16k/savee_OAF_fear_569...     fear   savee   OAF
# 3  ../data/processed/audio_16k/savee_OAF_sad_1114...      sad   savee   OAF
# 4  ../data/processed/audio_16k/savee_OAF_neutral_...  neutral   savee   OAF
#
#   index  sample_rate
# 0  1630        16000
# 1  1867        16000
# 2   569        16000
# 3  1114        16000
# 4   866        16000
