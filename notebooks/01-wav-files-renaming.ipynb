# %% [markdown]
# # WAV Files Renaming

# %% [markdown]
# ## Import Libraries

# %%
import os
import re
import sys
import importlib

# %% [markdown]
# ## Import Utils

# %%
sys.path.append("..")
import utils
from utils import identify_emotion

importlib.reload(utils)

from utils import identify_emotion

# %% [markdown]
# ## Crema-D Dataset

# %% [markdown]
# ### Configuration

# %%
crema_d_folder_path = r"../data/raw/crema-d"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
crema_d_wav_files = [f for f in os.listdir(crema_d_folder_path) if f.lower().endswith('.wav')]
crema_d_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(crema_d_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("_", name_without_ext)
    actor_id = parts[0]
    sentenceCode = parts[1]
    emotion_code = identify_emotion(parts[2])
    intensity_code = parts[3]
    new_name = f"crema-d_{actor_id}_{emotion_code}_{i}.wav"
    old_path = os.path.join(crema_d_folder_path, old_name)
    new_path = os.path.join(crema_d_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")

# %% [markdown]
# ## Ravdess Dataset

# %% [markdown]
# ### Configuration

# %%
ravdess_folder_path = r"../data/raw/ravdess"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
ravdess_wav_files = [f for f in os.listdir(ravdess_folder_path) if f.lower().endswith('.wav')]
ravdess_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(ravdess_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("-", name_without_ext)

    # Delete "02" and "08" files
    if parts[2] in ("02", "08"):
        old_path = os.path.join(ravdess_folder_path, old_name)
        if os.path.exists(old_path):
            os.remove(old_path)
            print(f"Deleted: {old_path}")
        continue;
    
    emotion_code = parts[2].strip()
    emotion = identify_emotion(emotion_code)
    
    actor_id = parts[6]
    new_name = f"ravdess_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(ravdess_folder_path, old_name)
    new_path = os.path.join(ravdess_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")

# %% [markdown]
# ## Savee Dataset

# %% [markdown]
# ### Configuration

# %%
savee_folder_path = r"../data/raw/savee"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
savee_wav_files = [f for f in os.listdir(savee_folder_path) if f.lower().endswith('.wav')]
savee_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(savee_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("_", name_without_ext)

    second_part = parts[1]
    emotion_code = ''.join(filter(str.isalpha, second_part))

    if emotion_code == "su":
        old_path = os.path.join(savee_folder_path, old_name)
        if os.path.exists(old_path):
            os.remove(old_path)
            print(f"Deleted: {old_path}")
        continue;
    
    emotion = identify_emotion(emotion_code)
    
    actor_id = parts[0]
    new_name = f"savee_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(savee_folder_path, old_name)
    new_path = os.path.join(savee_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")

# %% [markdown]
# ## Tess Dataset

# %% [markdown]
# ### Configuration

# %%
tess_folder_path = r"../data/raw/tess"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
tess_wav_files = [f for f in os.listdir(tess_folder_path) if f.lower().endswith('.wav')]
tess_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(tess_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("_", name_without_ext)

    emotion_code = parts[2]
    emotion = identify_emotion(emotion_code)
    
    actor_id = parts[0]
    new_name = f"savee_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(tess_folder_path, old_name)
    new_path = os.path.join(tess_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")

# %% [markdown]
# ## Subesco Dataset

# %% [markdown]
# ### Configuration

# %% [markdown]
# subesco_folder_path = r"../data/raw/subesco"
# start_number = 1
# number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
subesco_wav_files = [f for f in os.listdir(subesco_folder_path) if f.lower().endswith('.wav')]
subesco_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(subesco_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("_", name_without_ext.lower())

    emotion_code = parts[5]

    if emotion_code == "surprise":
        old_path = os.path.join(subesco_folder_path, old_name)
        if os.path.exists(old_path):
            os.remove(old_path)
            print(f"Deleted: {old_path}")
        continue;
    
    emotion = identify_emotion(emotion_code)
    
    actor_id = parts[0]
    new_name = f"subesco_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(subesco_folder_path, old_name)
    new_path = os.path.join(subesco_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")

# %% [markdown]
# ## Evomo Dataset

# %% [markdown]
# ### Configuration

# %%
emovo_folder_path = r"../data/raw/emovo"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
emovo_wav_files = [f for f in os.listdir(emovo_folder_path) if f.lower().endswith('.wav')]
emovo_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(emovo_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("-", name_without_ext.lower())

    emotion_code = parts[0]

    if emotion_code == "sor":
        old_path = os.path.join(emovo_folder_path, old_name)
        if os.path.exists(old_path):
            os.remove(old_path)
            print(f"Deleted: {old_path}")
        continue;
    
    emotion = identify_emotion(emotion_code)
    
    actor_id = parts[1]
    new_name = f"emovo_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(emovo_folder_path, old_name)
    new_path = os.path.join(emovo_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")

# %% [markdown]
# ## Emodb Dataset

# %% [markdown]
# ### Configuration

# %%
emodb_folder_path = r"../data/raw/emodb"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
emodb_wav_files = [f for f in os.listdir(emodb_folder_path) if f.lower().endswith('.wav')]
emodb_wav_files.sort()

def custom_identify_emotion(emotion):
    if not isinstance(emotion, str):
        return None  

    match emotion:
        case "W":
            return "angry"
        case "E":
            return "disgust"
        case "A":
            return "fear"
        case "F":
            return "happy"
        case "N":
            return "neutral"
        case "T":
            return "sad"

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(emodb_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = list(name_without_ext.lower())

    emotion_code = parts[5]

    if emotion_code == "l":
        old_path = os.path.join(emodb_folder_path, old_name)
        if os.path.exists(old_path):
            os.remove(old_path)
            print(f"Deleted: {old_path}")
        continue;
    
    emotion = custom_identify_emotion(emotion_code.upper())
    
    actor_id = parts[0] + parts[1]
    new_name = f"emodb_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(emodb_folder_path, old_name)
    new_path = os.path.join(emodb_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")
# Out:
# Renamed '03a01Fa.wav' -> 'emodb_03_happy_1.wav'
# Renamed '03a01Nc.wav' -> 'emodb_03_neutral_2.wav'
# Renamed '03a01Wa.wav' -> 'emodb_03_angry_3.wav'
# Renamed '03a02Fc.wav' -> 'emodb_03_happy_4.wav'
# Renamed '03a02Nc.wav' -> 'emodb_03_neutral_5.wav'
# Renamed '03a02Ta.wav' -> 'emodb_03_sad_6.wav'
# Renamed '03a02Wb.wav' -> 'emodb_03_angry_7.wav'
# Renamed '03a02Wc.wav' -> 'emodb_03_angry_8.wav'
# Renamed '03a04Ad.wav' -> 'emodb_03_fear_9.wav'
# Renamed '03a04Fd.wav' -> 'emodb_03_happy_10.wav'
# Deleted: ../data/raw/emodb/03a04Lc.wav
# Renamed '03a04Nc.wav' -> 'emodb_03_neutral_12.wav'
# Renamed '03a04Ta.wav' -> 'emodb_03_sad_13.wav'
# Renamed '03a04Wc.wav' -> 'emodb_03_angry_14.wav'
# Renamed '03a05Aa.wav' -> 'emodb_03_fear_15.wav'
# Renamed '03a05Fc.wav' -> 'emodb_03_happy_16.wav'
# Renamed '03a05Nd.wav' -> 'emodb_03_neutral_17.wav'
# Renamed '03a05Tc.wav' -> 'emodb_03_sad_18.wav'
# Renamed '03a05Wa.wav' -> 'emodb_03_angry_19.wav'
# Renamed '03a05Wb.wav' -> 'emodb_03_angry_20.wav'
# Renamed '03a07Fa.wav' -> 'emodb_03_happy_21.wav'
# Renamed '03a07Fb.wav' -> 'emodb_03_happy_22.wav'
# Deleted: ../data/raw/emodb/03a07La.wav
# Renamed '03a07Nc.wav' -> 'emodb_03_neutral_24.wav'
# Renamed '03a07Wc.wav' -> 'emodb_03_angry_25.wav'
# Renamed '03b01Fa.wav' -> 'emodb_03_happy_26.wav'
# Deleted: ../data/raw/emodb/03b01Lb.wav
# Renamed '03b01Nb.wav' -> 'emodb_03_neutral_28.wav'
# Renamed '03b01Td.wav' -> 'emodb_03_sad_29.wav'
# Renamed '03b01Wa.wav' -> 'emodb_03_angry_30.wav'
# Renamed '03b01Wc.wav' -> 'emodb_03_angry_31.wav'
# Renamed '03b02Aa.wav' -> 'emodb_03_fear_32.wav'
# Deleted: ../data/raw/emodb/03b02La.wav
# Renamed '03b02Na.wav' -> 'emodb_03_neutral_34.wav'
# Renamed '03b02Tb.wav' -> 'emodb_03_sad_35.wav'
# Renamed '03b02Wb.wav' -> 'emodb_03_angry_36.wav'
# Renamed '03b03Nb.wav' -> 'emodb_03_neutral_37.wav'
# Renamed '03b03Tc.wav' -> 'emodb_03_sad_38.wav'
# Renamed '03b03Wc.wav' -> 'emodb_03_angry_39.wav'
# Deleted: ../data/raw/emodb/03b09La.wav
# Renamed '03b09Nc.wav' -> 'emodb_03_neutral_41.wav'
# Renamed '03b09Tc.wav' -> 'emodb_03_sad_42.wav'
# Renamed '03b09Wa.wav' -> 'emodb_03_angry_43.wav'
# Renamed '03b10Ab.wav' -> 'emodb_03_fear_44.wav'
# Renamed '03b10Ec.wav' -> 'emodb_03_disgust_45.wav'
# Renamed '03b10Na.wav' -> 'emodb_03_neutral_46.wav'
# Renamed '03b10Nc.wav' -> 'emodb_03_neutral_47.wav'
# Renamed '03b10Wb.wav' -> 'emodb_03_angry_48.wav'
# Renamed '03b10Wc.wav' -> 'emodb_03_angry_49.wav'
# Renamed '08a01Ab.wav' -> 'emodb_08_fear_50.wav'
# Renamed '08a01Fd.wav' -> 'emodb_08_happy_51.wav'
# Deleted: ../data/raw/emodb/08a01Lc.wav
# Renamed '08a01Na.wav' -> 'emodb_08_neutral_53.wav'
# Renamed '08a01Wa.wav' -> 'emodb_08_angry_54.wav'
# Renamed '08a01Wc.wav' -> 'emodb_08_angry_55.wav'
# Renamed '08a02Ab.wav' -> 'emodb_08_fear_56.wav'
# Renamed '08a02Ac.wav' -> 'emodb_08_fear_57.wav'
# Renamed '08a02Fe.wav' -> 'emodb_08_happy_58.wav'
# Deleted: ../data/raw/emodb/08a02La.wav
# Renamed '08a02Na.wav' -> 'emodb_08_neutral_60.wav'
# Renamed '08a02Tb.wav' -> 'emodb_08_sad_61.wav'
# Renamed '08a02Wc.wav' -> 'emodb_08_angry_62.wav'
# Renamed '08a04Ff.wav' -> 'emodb_08_happy_63.wav'
# Deleted: ../data/raw/emodb/08a04La.wav
# Renamed '08a04Nc.wav' -> 'emodb_08_neutral_65.wav'
# Renamed '08a04Tb.wav' -> 'emodb_08_sad_66.wav'
# Renamed '08a04Wc.wav' -> 'emodb_08_angry_67.wav'
# Renamed '08a05Fe.wav' -> 'emodb_08_happy_68.wav'
# Deleted: ../data/raw/emodb/08a05Lc.wav
# Renamed '08a05Nb.wav' -> 'emodb_08_neutral_70.wav'
# Renamed '08a05Ta.wav' -> 'emodb_08_sad_71.wav'
# Renamed '08a05Wa.wav' -> 'emodb_08_angry_72.wav'
# Renamed '08a07Fd.wav' -> 'emodb_08_happy_73.wav'
# Deleted: ../data/raw/emodb/08a07La.wav
# Renamed '08a07Na.wav' -> 'emodb_08_neutral_75.wav'
# Renamed '08a07Ta.wav' -> 'emodb_08_sad_76.wav'
# Renamed '08a07Tb.wav' -> 'emodb_08_sad_77.wav'
# Renamed '08a07Wc.wav' -> 'emodb_08_angry_78.wav'
# Renamed '08b01Aa.wav' -> 'emodb_08_fear_79.wav'
# Renamed '08b01Fd.wav' -> 'emodb_08_happy_80.wav'
# Renamed '08b01Fe.wav' -> 'emodb_08_happy_81.wav'
# Deleted: ../data/raw/emodb/08b01Lb.wav
# Renamed '08b01Na.wav' -> 'emodb_08_neutral_83.wav'
# Renamed '08b01Wa.wav' -> 'emodb_08_angry_84.wav'
# Renamed '08b02Ff.wav' -> 'emodb_08_happy_85.wav'
# Deleted: ../data/raw/emodb/08b02La.wav
# Renamed '08b02Nb.wav' -> 'emodb_08_neutral_87.wav'
# Renamed '08b02Tc.wav' -> 'emodb_08_sad_88.wav'
# Renamed '08b02Wd.wav' -> 'emodb_08_angry_89.wav'
# Renamed '08b03Fe.wav' -> 'emodb_08_happy_90.wav'
# Deleted: ../data/raw/emodb/08b03Lc.wav
# Renamed '08b03Nb.wav' -> 'emodb_08_neutral_92.wav'
# Renamed '08b03Tc.wav' -> 'emodb_08_sad_93.wav'
# Renamed '08b03Wd.wav' -> 'emodb_08_angry_94.wav'
# Renamed '08b09Ab.wav' -> 'emodb_08_fear_95.wav'
# Renamed '08b09Fd.wav' -> 'emodb_08_happy_96.wav'
# Deleted: ../data/raw/emodb/08b09Lc.wav
# Renamed '08b09Nb.wav' -> 'emodb_08_neutral_98.wav'
# Renamed '08b09Tb.wav' -> 'emodb_08_sad_99.wav'
# Renamed '08b09Wa.wav' -> 'emodb_08_angry_100.wav'
# Renamed '08b09Wc.wav' -> 'emodb_08_angry_101.wav'
# Renamed '08b10Aa.wav' -> 'emodb_08_fear_102.wav'
# Renamed '08b10Fd.wav' -> 'emodb_08_happy_103.wav'
# Deleted: ../data/raw/emodb/08b10La.wav
# Renamed '08b10Nc.wav' -> 'emodb_08_neutral_105.wav'
# Renamed '08b10Tc.wav' -> 'emodb_08_sad_106.wav'
# Renamed '08b10Wa.wav' -> 'emodb_08_angry_107.wav'
# Renamed '09a01Ea.wav' -> 'emodb_09_disgust_108.wav'
# Renamed '09a01Fa.wav' -> 'emodb_09_happy_109.wav'
# Renamed '09a01Nb.wav' -> 'emodb_09_neutral_110.wav'
# Renamed '09a01Wb.wav' -> 'emodb_09_angry_111.wav'
# Renamed '09a02Ea.wav' -> 'emodb_09_disgust_112.wav'
# Renamed '09a02Eb.wav' -> 'emodb_09_disgust_113.wav'
# Deleted: ../data/raw/emodb/09a02La.wav
# Renamed '09a02Wb.wav' -> 'emodb_09_angry_115.wav'
# Renamed '09a04Fd.wav' -> 'emodb_09_happy_116.wav'
# Deleted: ../data/raw/emodb/09a04La.wav
# Renamed '09a04Nb.wav' -> 'emodb_09_neutral_118.wav'
# Renamed '09a04Wa.wav' -> 'emodb_09_angry_119.wav'
# Renamed '09a05Ed.wav' -> 'emodb_09_disgust_120.wav'
# Deleted: ../data/raw/emodb/09a05Lc.wav
# Renamed '09a05Nb.wav' -> 'emodb_09_neutral_122.wav'
# Renamed '09a05Tb.wav' -> 'emodb_09_sad_123.wav'
# Renamed '09a05Wb.wav' -> 'emodb_09_angry_124.wav'
# Renamed '09a05Wc.wav' -> 'emodb_09_angry_125.wav'
# Renamed '09a07Eb.wav' -> 'emodb_09_disgust_126.wav'
# Renamed '09a07Na.wav' -> 'emodb_09_neutral_127.wav'
# Renamed '09a07Ta.wav' -> 'emodb_09_sad_128.wav'
# Renamed '09a07Wb.wav' -> 'emodb_09_angry_129.wav'
# Renamed '09a07Wd.wav' -> 'emodb_09_angry_130.wav'
# Renamed '09b01Ea.wav' -> 'emodb_09_disgust_131.wav'
# Renamed '09b01Na.wav' -> 'emodb_09_neutral_132.wav'
# Renamed '09b01Wb.wav' -> 'emodb_09_angry_133.wav'
# Renamed '09b02Na.wav' -> 'emodb_09_neutral_134.wav'
# Renamed '09b02Tb.wav' -> 'emodb_09_sad_135.wav'
# Renamed '09b02Wc.wav' -> 'emodb_09_angry_136.wav'
# Renamed '09b02Wd.wav' -> 'emodb_09_angry_137.wav'
# Renamed '09b03Ed.wav' -> 'emodb_09_disgust_138.wav'
# Renamed '09b03Fa.wav' -> 'emodb_09_happy_139.wav'
# Renamed '09b03Fd.wav' -> 'emodb_09_happy_140.wav'
# Deleted: ../data/raw/emodb/09b03Lb.wav
# Renamed '09b03Nb.wav' -> 'emodb_09_neutral_142.wav'
# Renamed '09b03Ta.wav' -> 'emodb_09_sad_143.wav'
# Renamed '09b03Wb.wav' -> 'emodb_09_angry_144.wav'
# Renamed '09b09Ea.wav' -> 'emodb_09_disgust_145.wav'
# Renamed '09b09Nd.wav' -> 'emodb_09_neutral_146.wav'
# Renamed '09b09Wa.wav' -> 'emodb_09_angry_147.wav'
# Renamed '09b10Aa.wav' -> 'emodb_09_fear_148.wav'
# Renamed '09b10Nd.wav' -> 'emodb_09_neutral_149.wav'
# Renamed '09b10Wa.wav' -> 'emodb_09_angry_150.wav'
# Renamed '10a01Ac.wav' -> 'emodb_10_fear_151.wav'
# Renamed '10a01Nb.wav' -> 'emodb_10_neutral_152.wav'
# Renamed '10a01Wa.wav' -> 'emodb_10_angry_153.wav'
# Renamed '10a02Ab.wav' -> 'emodb_10_fear_154.wav'
# Renamed '10a02Fa.wav' -> 'emodb_10_happy_155.wav'
# Deleted: ../data/raw/emodb/10a02Lb.wav
# Renamed '10a02Na.wav' -> 'emodb_10_neutral_157.wav'
# Renamed '10a02Wa.wav' -> 'emodb_10_angry_158.wav'
# Renamed '10a04Fd.wav' -> 'emodb_10_happy_159.wav'
# Renamed '10a04Nb.wav' -> 'emodb_10_neutral_160.wav'
# Renamed '10a04Wa.wav' -> 'emodb_10_angry_161.wav'
# Renamed '10a04Wb.wav' -> 'emodb_10_angry_162.wav'
# Renamed '10a05Aa.wav' -> 'emodb_10_fear_163.wav'
# Deleted: ../data/raw/emodb/10a05Ld.wav
# Renamed '10a05Tb.wav' -> 'emodb_10_sad_165.wav'
# Renamed '10a05Wb.wav' -> 'emodb_10_angry_166.wav'
# Renamed '10a07Aa.wav' -> 'emodb_10_fear_167.wav'
# Renamed '10a07Ad.wav' -> 'emodb_10_fear_168.wav'
# Deleted: ../data/raw/emodb/10a07La.wav
# Renamed '10a07Ta.wav' -> 'emodb_10_sad_170.wav'
# Renamed '10a07Wb.wav' -> 'emodb_10_angry_171.wav'
# Renamed '10b01Aa.wav' -> 'emodb_10_fear_172.wav'
# Renamed '10b01Ea.wav' -> 'emodb_10_disgust_173.wav'
# Renamed '10b01Fa.wav' -> 'emodb_10_happy_174.wav'
# Deleted: ../data/raw/emodb/10b01Lb.wav
# Renamed '10b02Aa.wav' -> 'emodb_10_fear_176.wav'
# Deleted: ../data/raw/emodb/10b02La.wav
# Renamed '10b02Na.wav' -> 'emodb_10_neutral_178.wav'
# Renamed '10b02Wb.wav' -> 'emodb_10_angry_179.wav'
# Deleted: ../data/raw/emodb/10b03La.wav
# Renamed '10b03Tb.wav' -> 'emodb_10_sad_181.wav'
# Renamed '10b03Wb.wav' -> 'emodb_10_angry_182.wav'
# Renamed '10b09Ad.wav' -> 'emodb_10_fear_183.wav'
# Deleted: ../data/raw/emodb/10b09Lb.wav
# Renamed '10b09Wb.wav' -> 'emodb_10_angry_185.wav'
# Renamed '10b10Fc.wav' -> 'emodb_10_happy_186.wav'
# Deleted: ../data/raw/emodb/10b10Lc.wav
# Renamed '10b10Wa.wav' -> 'emodb_10_angry_188.wav'
# Renamed '11a01Aa.wav' -> 'emodb_11_fear_189.wav'
# Renamed '11a01Ab.wav' -> 'emodb_11_fear_190.wav'
# Deleted: ../data/raw/emodb/11a01Ld.wav
# Renamed '11a01Nd.wav' -> 'emodb_11_neutral_192.wav'
# Renamed '11a01Wc.wav' -> 'emodb_11_angry_193.wav'
# Renamed '11a02Ec.wav' -> 'emodb_11_disgust_194.wav'
# Renamed '11a02Fb.wav' -> 'emodb_11_happy_195.wav'
# Deleted: ../data/raw/emodb/11a02Ld.wav
# Renamed '11a02Nc.wav' -> 'emodb_11_neutral_197.wav'
# Renamed '11a02Tc.wav' -> 'emodb_11_sad_198.wav'
# Renamed '11a02Wc.wav' -> 'emodb_11_angry_199.wav'
# Renamed '11a04Ac.wav' -> 'emodb_11_fear_200.wav'
# Renamed '11a04Fd.wav' -> 'emodb_11_happy_201.wav'
# Renamed '11a04Nd.wav' -> 'emodb_11_neutral_202.wav'
# Renamed '11a04Wc.wav' -> 'emodb_11_angry_203.wav'
# Renamed '11a05Ad.wav' -> 'emodb_11_fear_204.wav'
# Renamed '11a05Fb.wav' -> 'emodb_11_happy_205.wav'
# Renamed '11a05Fc.wav' -> 'emodb_11_happy_206.wav'
# Deleted: ../data/raw/emodb/11a05Lc.wav
# Renamed '11a05Na.wav' -> 'emodb_11_neutral_208.wav'
# Renamed '11a05Td.wav' -> 'emodb_11_sad_209.wav'
# Renamed '11a05Wd.wav' -> 'emodb_11_angry_210.wav'
# Renamed '11a07Ac.wav' -> 'emodb_11_fear_211.wav'
# Deleted: ../data/raw/emodb/11a07Ld.wav
# Renamed '11a07Ta.wav' -> 'emodb_11_sad_213.wav'
# Renamed '11a07Wc.wav' -> 'emodb_11_angry_214.wav'
# Renamed '11b01Ab.wav' -> 'emodb_11_fear_215.wav'
# Renamed '11b01Eb.wav' -> 'emodb_11_disgust_216.wav'
# Renamed '11b01Fc.wav' -> 'emodb_11_happy_217.wav'
# Deleted: ../data/raw/emodb/11b01Lb.wav
# Renamed '11b01Nc.wav' -> 'emodb_11_neutral_219.wav'
# Renamed '11b01Wd.wav' -> 'emodb_11_angry_220.wav'
# Renamed '11b02Ab.wav' -> 'emodb_11_fear_221.wav'
# Renamed '11b02Fd.wav' -> 'emodb_11_happy_222.wav'
# Renamed '11b02Na.wav' -> 'emodb_11_neutral_223.wav'
# Renamed '11b02Td.wav' -> 'emodb_11_sad_224.wav'
# Renamed '11b02Wb.wav' -> 'emodb_11_angry_225.wav'
# Renamed '11b03Fc.wav' -> 'emodb_11_happy_226.wav'
# Deleted: ../data/raw/emodb/11b03Lc.wav
# Renamed '11b03Nb.wav' -> 'emodb_11_neutral_228.wav'
# Renamed '11b03Td.wav' -> 'emodb_11_sad_229.wav'
# Renamed '11b03Wa.wav' -> 'emodb_11_angry_230.wav'
# Renamed '11b03Wb.wav' -> 'emodb_11_angry_231.wav'
# Renamed '11b09Ad.wav' -> 'emodb_11_fear_232.wav'
# Renamed '11b09Fd.wav' -> 'emodb_11_happy_233.wav'
# Deleted: ../data/raw/emodb/11b09Ld.wav
# Renamed '11b09Na.wav' -> 'emodb_11_neutral_235.wav'
# Renamed '11b09Td.wav' -> 'emodb_11_sad_236.wav'
# Renamed '11b09Wa.wav' -> 'emodb_11_angry_237.wav'
# Renamed '11b10Ad.wav' -> 'emodb_11_fear_238.wav'
# Renamed '11b10Ae.wav' -> 'emodb_11_fear_239.wav'
# Deleted: ../data/raw/emodb/11b10Ld.wav
# Renamed '11b10Nc.wav' -> 'emodb_11_neutral_241.wav'
# Renamed '11b10Td.wav' -> 'emodb_11_sad_242.wav'
# Renamed '11b10Wa.wav' -> 'emodb_11_angry_243.wav'
# Renamed '12a01Fb.wav' -> 'emodb_12_happy_244.wav'
# Deleted: ../data/raw/emodb/12a01Lb.wav
# Renamed '12a01Nb.wav' -> 'emodb_12_neutral_246.wav'
# Renamed '12a01Wc.wav' -> 'emodb_12_angry_247.wav'
# Renamed '12a02Ac.wav' -> 'emodb_12_fear_248.wav'
# Renamed '12a02Ec.wav' -> 'emodb_12_disgust_249.wav'
# Renamed '12a02Nb.wav' -> 'emodb_12_neutral_250.wav'
# Renamed '12a02Wa.wav' -> 'emodb_12_angry_251.wav'
# Renamed '12a02Wc.wav' -> 'emodb_12_angry_252.wav'
# Renamed '12a04Wc.wav' -> 'emodb_12_angry_253.wav'
# Renamed '12a05Ab.wav' -> 'emodb_12_fear_254.wav'
# Deleted: ../data/raw/emodb/12a05Lb.wav
# Renamed '12a05Nd.wav' -> 'emodb_12_neutral_256.wav'
# Renamed '12a05Ta.wav' -> 'emodb_12_sad_257.wav'
# Renamed '12a05Wb.wav' -> 'emodb_12_angry_258.wav'
# Renamed '12a07Ac.wav' -> 'emodb_12_fear_259.wav'
# Deleted: ../data/raw/emodb/12a07La.wav
# Renamed '12a07Wa.wav' -> 'emodb_12_angry_261.wav'
# Renamed '12b01Ta.wav' -> 'emodb_12_sad_262.wav'
# Renamed '12b01Wa.wav' -> 'emodb_12_angry_263.wav'
# Renamed '12b02Ad.wav' -> 'emodb_12_fear_264.wav'
# Renamed '12b02Ea.wav' -> 'emodb_12_disgust_265.wav'
# Renamed '12b02Fb.wav' -> 'emodb_12_happy_266.wav'
# Renamed '12b02Na.wav' -> 'emodb_12_neutral_267.wav'
# Renamed '12b02Wa.wav' -> 'emodb_12_angry_268.wav'
# Renamed '12b02Wb.wav' -> 'emodb_12_angry_269.wav'
# Renamed '12b02Wd.wav' -> 'emodb_12_angry_270.wav'
# Deleted: ../data/raw/emodb/12b03La.wav
# Renamed '12b03Ta.wav' -> 'emodb_12_sad_272.wav'
# Renamed '12b09Ac.wav' -> 'emodb_12_fear_273.wav'
# Renamed '12b09Td.wav' -> 'emodb_12_sad_274.wav'
# Renamed '12b09Wc.wav' -> 'emodb_12_angry_275.wav'
# Renamed '12b10Ac.wav' -> 'emodb_12_fear_276.wav'
# Deleted: ../data/raw/emodb/12b10Ld.wav
# Renamed '12b10Wa.wav' -> 'emodb_12_angry_278.wav'
# Renamed '13a01Ac.wav' -> 'emodb_13_fear_279.wav'
# Renamed '13a01Ea.wav' -> 'emodb_13_disgust_280.wav'
# Renamed '13a01Ec.wav' -> 'emodb_13_disgust_281.wav'
# Renamed '13a01Fd.wav' -> 'emodb_13_happy_282.wav'
# Deleted: ../data/raw/emodb/13a01Lb.wav
# Renamed '13a01Nb.wav' -> 'emodb_13_neutral_284.wav'
# Renamed '13a01Wb.wav' -> 'emodb_13_angry_285.wav'
# Renamed '13a02Ad.wav' -> 'emodb_13_fear_286.wav'
# Renamed '13a02Ec.wav' -> 'emodb_13_disgust_287.wav'
# Renamed '13a02Fa.wav' -> 'emodb_13_happy_288.wav'
# Deleted: ../data/raw/emodb/13a02Lc.wav
# Renamed '13a02Nc.wav' -> 'emodb_13_neutral_290.wav'
# Renamed '13a02Ta.wav' -> 'emodb_13_sad_291.wav'
# Renamed '13a02Wa.wav' -> 'emodb_13_angry_292.wav'
# Renamed '13a04Ac.wav' -> 'emodb_13_fear_293.wav'
# Renamed '13a04Fc.wav' -> 'emodb_13_happy_294.wav'
# Deleted: ../data/raw/emodb/13a04Lb.wav
# Renamed '13a04Ta.wav' -> 'emodb_13_sad_296.wav'
# Renamed '13a04Wc.wav' -> 'emodb_13_angry_297.wav'
# Renamed '13a05Aa.wav' -> 'emodb_13_fear_298.wav'
# Renamed '13a05Ea.wav' -> 'emodb_13_disgust_299.wav'
# Deleted: ../data/raw/emodb/13a05Lc.wav
# Renamed '13a05Nb.wav' -> 'emodb_13_neutral_301.wav'
# Renamed '13a05Tc.wav' -> 'emodb_13_sad_302.wav'
# Renamed '13a05Wa.wav' -> 'emodb_13_angry_303.wav'
# Renamed '13a05Wc.wav' -> 'emodb_13_angry_304.wav'
# Renamed '13a07Fd.wav' -> 'emodb_13_happy_305.wav'
# Deleted: ../data/raw/emodb/13a07Lb.wav
# Renamed '13a07Na.wav' -> 'emodb_13_neutral_307.wav'
# Renamed '13a07Tc.wav' -> 'emodb_13_sad_308.wav'
# Renamed '13a07Wb.wav' -> 'emodb_13_angry_309.wav'
# Renamed '13b01Ab.wav' -> 'emodb_13_fear_310.wav'
# Renamed '13b01Ec.wav' -> 'emodb_13_disgust_311.wav'
# Renamed '13b01Fc.wav' -> 'emodb_13_happy_312.wav'
# Deleted: ../data/raw/emodb/13b01Ld.wav
# Renamed '13b01Nc.wav' -> 'emodb_13_neutral_314.wav'
# Renamed '13b01Wa.wav' -> 'emodb_13_angry_315.wav'
# Renamed '13b02Fb.wav' -> 'emodb_13_happy_316.wav'
# Deleted: ../data/raw/emodb/13b02Lc.wav
# Renamed '13b02Nb.wav' -> 'emodb_13_neutral_318.wav'
# Renamed '13b02Wa.wav' -> 'emodb_13_angry_319.wav'
# Renamed '13b03Ac.wav' -> 'emodb_13_fear_320.wav'
# Renamed '13b03Ed.wav' -> 'emodb_13_disgust_321.wav'
# Renamed '13b03Fd.wav' -> 'emodb_13_happy_322.wav'
# Deleted: ../data/raw/emodb/13b03Lb.wav
# Renamed '13b03Na.wav' -> 'emodb_13_neutral_324.wav'
# Renamed '13b03Td.wav' -> 'emodb_13_sad_325.wav'
# Renamed '13b03Wc.wav' -> 'emodb_13_angry_326.wav'
# Renamed '13b09Ab.wav' -> 'emodb_13_fear_327.wav'
# Renamed '13b09Ec.wav' -> 'emodb_13_disgust_328.wav'
# Renamed '13b09Fb.wav' -> 'emodb_13_happy_329.wav'
# Renamed '13b09Fc.wav' -> 'emodb_13_happy_330.wav'
# Deleted: ../data/raw/emodb/13b09La.wav
# Renamed '13b09Na.wav' -> 'emodb_13_neutral_332.wav'
# Renamed '13b09Wa.wav' -> 'emodb_13_angry_333.wav'
# Renamed '13b10Ec.wav' -> 'emodb_13_disgust_334.wav'
# Renamed '13b10Fa.wav' -> 'emodb_13_happy_335.wav'
# Deleted: ../data/raw/emodb/13b10La.wav
# Renamed '13b10Nc.wav' -> 'emodb_13_neutral_337.wav'
# Renamed '13b10Wa.wav' -> 'emodb_13_angry_338.wav'
# Renamed '13b10Wc.wav' -> 'emodb_13_angry_339.wav'
# Renamed '14a01Aa.wav' -> 'emodb_14_fear_340.wav'
# Renamed '14a01Ac.wav' -> 'emodb_14_fear_341.wav'
# Renamed '14a01Ea.wav' -> 'emodb_14_disgust_342.wav'
# Renamed '14a01Na.wav' -> 'emodb_14_neutral_343.wav'
# Renamed '14a01Wa.wav' -> 'emodb_14_angry_344.wav'
# Renamed '14a01Wc.wav' -> 'emodb_14_angry_345.wav'
# Renamed '14a02Ab.wav' -> 'emodb_14_fear_346.wav'
# Renamed '14a02Ea.wav' -> 'emodb_14_disgust_347.wav'
# Renamed '14a02Fd.wav' -> 'emodb_14_happy_348.wav'
# Deleted: ../data/raw/emodb/14a02La.wav
# Renamed '14a02Nc.wav' -> 'emodb_14_neutral_350.wav'
# Renamed '14a02Tb.wav' -> 'emodb_14_sad_351.wav'
# Renamed '14a02Wa.wav' -> 'emodb_14_angry_352.wav'
# Renamed '14a02Wc.wav' -> 'emodb_14_angry_353.wav'
# Renamed '14a04Aa.wav' -> 'emodb_14_fear_354.wav'
# Renamed '14a04Ed.wav' -> 'emodb_14_disgust_355.wav'
# Deleted: ../data/raw/emodb/14a04Lb.wav
# Renamed '14a04Tb.wav' -> 'emodb_14_sad_357.wav'
# Renamed '14a04Tc.wav' -> 'emodb_14_sad_358.wav'
# Renamed '14a04Wb.wav' -> 'emodb_14_angry_359.wav'
# Renamed '14a04Wc.wav' -> 'emodb_14_angry_360.wav'
# Renamed '14a05Aa.wav' -> 'emodb_14_fear_361.wav'
# Renamed '14a05Ac.wav' -> 'emodb_14_fear_362.wav'
# Renamed '14a05Fa.wav' -> 'emodb_14_happy_363.wav'
# Renamed '14a05Fb.wav' -> 'emodb_14_happy_364.wav'
# Deleted: ../data/raw/emodb/14a05Lb.wav
# Renamed '14a05Na.wav' -> 'emodb_14_neutral_366.wav'
# Renamed '14a05Ta.wav' -> 'emodb_14_sad_367.wav'
# Renamed '14a05Tc.wav' -> 'emodb_14_sad_368.wav'
# Renamed '14a05Wa.wav' -> 'emodb_14_angry_369.wav'
# Renamed '14a05Wb.wav' -> 'emodb_14_angry_370.wav'
# Renamed '14a07Aa.wav' -> 'emodb_14_fear_371.wav'
# Renamed '14a07Eb.wav' -> 'emodb_14_disgust_372.wav'
# Renamed '14a07Fd.wav' -> 'emodb_14_happy_373.wav'
# Deleted: ../data/raw/emodb/14a07Lc.wav
# Deleted: ../data/raw/emodb/14a07Ld.wav
# Renamed '14a07Na.wav' -> 'emodb_14_neutral_376.wav'
# Renamed '14a07Tc.wav' -> 'emodb_14_sad_377.wav'
# Renamed '14a07Wc.wav' -> 'emodb_14_angry_378.wav'
# Renamed '14b01Ac.wav' -> 'emodb_14_fear_379.wav'
# Renamed '14b01Eb.wav' -> 'emodb_14_disgust_380.wav'
# Renamed '14b01Fa.wav' -> 'emodb_14_happy_381.wav'
# Renamed '14b01Fc.wav' -> 'emodb_14_happy_382.wav'
# Renamed '14b01Na.wav' -> 'emodb_14_neutral_383.wav'
# Renamed '14b01Wc.wav' -> 'emodb_14_angry_384.wav'
# Renamed '14b02Aa.wav' -> 'emodb_14_fear_385.wav'
# Renamed '14b02Fb.wav' -> 'emodb_14_happy_386.wav'
# Renamed '14b02Na.wav' -> 'emodb_14_neutral_387.wav'
# Renamed '14b02Tc.wav' -> 'emodb_14_sad_388.wav'
# Renamed '14b02Wb.wav' -> 'emodb_14_angry_389.wav'
# Renamed '14b02Wd.wav' -> 'emodb_14_angry_390.wav'
# Renamed '14b03Ad.wav' -> 'emodb_14_fear_391.wav'
# Renamed '14b03Ed.wav' -> 'emodb_14_disgust_392.wav'
# Deleted: ../data/raw/emodb/14b03Lb.wav
# Renamed '14b03Ta.wav' -> 'emodb_14_sad_394.wav'
# Renamed '14b03Wb.wav' -> 'emodb_14_angry_395.wav'
# Renamed '14b09Ac.wav' -> 'emodb_14_fear_396.wav'
# Renamed '14b09Ea.wav' -> 'emodb_14_disgust_397.wav'
# Renamed '14b09Fc.wav' -> 'emodb_14_happy_398.wav'
# Deleted: ../data/raw/emodb/14b09Lb.wav
# Renamed '14b09Td.wav' -> 'emodb_14_sad_400.wav'
# Renamed '14b09Wa.wav' -> 'emodb_14_angry_401.wav'
# Renamed '14b09Wc.wav' -> 'emodb_14_angry_402.wav'
# Renamed '14b10Ad.wav' -> 'emodb_14_fear_403.wav'
# Renamed '14b10Eb.wav' -> 'emodb_14_disgust_404.wav'
# Deleted: ../data/raw/emodb/14b10Lb.wav
# Renamed '14b10Nb.wav' -> 'emodb_14_neutral_406.wav'
# Renamed '14b10Tc.wav' -> 'emodb_14_sad_407.wav'
# Renamed '14b10Wc.wav' -> 'emodb_14_angry_408.wav'
# Renamed '15a01Ea.wav' -> 'emodb_15_disgust_409.wav'
# Renamed '15a01Fb.wav' -> 'emodb_15_happy_410.wav'
# Deleted: ../data/raw/emodb/15a01La.wav
# Renamed '15a01Nb.wav' -> 'emodb_15_neutral_412.wav'
# Renamed '15a01Wa.wav' -> 'emodb_15_angry_413.wav'
# Renamed '15a02Ac.wav' -> 'emodb_15_fear_414.wav'
# Renamed '15a02Ea.wav' -> 'emodb_15_disgust_415.wav'
# Deleted: ../data/raw/emodb/15a02La.wav
# Renamed '15a02Na.wav' -> 'emodb_15_neutral_417.wav'
# Renamed '15a02Ta.wav' -> 'emodb_15_sad_418.wav'
# Renamed '15a02Wb.wav' -> 'emodb_15_angry_419.wav'
# Renamed '15a02Wd.wav' -> 'emodb_15_angry_420.wav'
# Renamed '15a04Ab.wav' -> 'emodb_15_fear_421.wav'
# Renamed '15a04Ac.wav' -> 'emodb_15_fear_422.wav'
# Renamed '15a04Fd.wav' -> 'emodb_15_happy_423.wav'
# Renamed '15a04Nc.wav' -> 'emodb_15_neutral_424.wav'
# Renamed '15a04Wa.wav' -> 'emodb_15_angry_425.wav'
# Renamed '15a04Wb.wav' -> 'emodb_15_angry_426.wav'
# Renamed '15a05Eb.wav' -> 'emodb_15_disgust_427.wav'
# Renamed '15a05Fb.wav' -> 'emodb_15_happy_428.wav'
# Deleted: ../data/raw/emodb/15a05Lb.wav
# Renamed '15a05Na.wav' -> 'emodb_15_neutral_430.wav'
# Renamed '15a05Wa.wav' -> 'emodb_15_angry_431.wav'
# Renamed '15a07Ac.wav' -> 'emodb_15_fear_432.wav'
# Renamed '15a07Eb.wav' -> 'emodb_15_disgust_433.wav'
# Renamed '15a07Fa.wav' -> 'emodb_15_happy_434.wav'
# Renamed '15a07Fb.wav' -> 'emodb_15_happy_435.wav'
# Deleted: ../data/raw/emodb/15a07Ld.wav
# Renamed '15a07Nc.wav' -> 'emodb_15_neutral_437.wav'
# Renamed '15b01Ec.wav' -> 'emodb_15_disgust_438.wav'
# Deleted: ../data/raw/emodb/15b01Lb.wav
# Renamed '15b01Na.wav' -> 'emodb_15_neutral_440.wav'
# Renamed '15b01Wc.wav' -> 'emodb_15_angry_441.wav'
# Renamed '15b02Aa.wav' -> 'emodb_15_fear_442.wav'
# Deleted: ../data/raw/emodb/15b02Lb.wav
# Renamed '15b02Nd.wav' -> 'emodb_15_neutral_444.wav'
# Renamed '15b02Tc.wav' -> 'emodb_15_sad_445.wav'
# Renamed '15b02Wa.wav' -> 'emodb_15_angry_446.wav'
# Renamed '15b02Wc.wav' -> 'emodb_15_angry_447.wav'
# Renamed '15b03Aa.wav' -> 'emodb_15_fear_448.wav'
# Deleted: ../data/raw/emodb/15b03Lc.wav
# Renamed '15b03Nb.wav' -> 'emodb_15_neutral_450.wav'
# Renamed '15b03Tc.wav' -> 'emodb_15_sad_451.wav'
# Renamed '15b03Wa.wav' -> 'emodb_15_angry_452.wav'
# Renamed '15b03Wb.wav' -> 'emodb_15_angry_453.wav'
# Renamed '15b09Ac.wav' -> 'emodb_15_fear_454.wav'
# Renamed '15b09Fa.wav' -> 'emodb_15_happy_455.wav'
# Deleted: ../data/raw/emodb/15b09La.wav
# Renamed '15b09Nb.wav' -> 'emodb_15_neutral_457.wav'
# Renamed '15b09Ta.wav' -> 'emodb_15_sad_458.wav'
# Renamed '15b09Wb.wav' -> 'emodb_15_angry_459.wav'
# Renamed '15b10Ac.wav' -> 'emodb_15_fear_460.wav'
# Deleted: ../data/raw/emodb/15b10Lc.wav
# Renamed '15b10Nb.wav' -> 'emodb_15_neutral_462.wav'
# Renamed '15b10Nc.wav' -> 'emodb_15_neutral_463.wav'
# Renamed '15b10Wa.wav' -> 'emodb_15_angry_464.wav'
# Renamed '16a01Ec.wav' -> 'emodb_16_disgust_465.wav'
# Renamed '16a01Fc.wav' -> 'emodb_16_happy_466.wav'
# Deleted: ../data/raw/emodb/16a01Lb.wav
# Renamed '16a01Nc.wav' -> 'emodb_16_neutral_468.wav'
# Renamed '16a01Tb.wav' -> 'emodb_16_sad_469.wav'
# Renamed '16a01Wb.wav' -> 'emodb_16_angry_470.wav'
# Renamed '16a02Ea.wav' -> 'emodb_16_disgust_471.wav'
# Renamed '16a02Ec.wav' -> 'emodb_16_disgust_472.wav'
# Deleted: ../data/raw/emodb/16a02Lb.wav
# Renamed '16a02Nb.wav' -> 'emodb_16_neutral_474.wav'
# Renamed '16a02Tc.wav' -> 'emodb_16_sad_475.wav'
# Renamed '16a02Wb.wav' -> 'emodb_16_angry_476.wav'
# Renamed '16a04Ab.wav' -> 'emodb_16_fear_477.wav'
# Renamed '16a04Ea.wav' -> 'emodb_16_disgust_478.wav'
# Renamed '16a04Fa.wav' -> 'emodb_16_happy_479.wav'
# Deleted: ../data/raw/emodb/16a04La.wav
# Deleted: ../data/raw/emodb/16a04Lc.wav
# Renamed '16a04Nc.wav' -> 'emodb_16_neutral_482.wav'
# Renamed '16a04Tc.wav' -> 'emodb_16_sad_483.wav'
# Renamed '16a04Wb.wav' -> 'emodb_16_angry_484.wav'
# Renamed '16a04Wc.wav' -> 'emodb_16_angry_485.wav'
# Renamed '16a05Ab.wav' -> 'emodb_16_fear_486.wav'
# Renamed '16a05Ea.wav' -> 'emodb_16_disgust_487.wav'
# Renamed '16a05Fc.wav' -> 'emodb_16_happy_488.wav'
# Deleted: ../data/raw/emodb/16a05La.wav
# Renamed '16a05Tb.wav' -> 'emodb_16_sad_490.wav'
# Renamed '16a05Wb.wav' -> 'emodb_16_angry_491.wav'
# Renamed '16a05Wc.wav' -> 'emodb_16_angry_492.wav'
# Renamed '16a07Ea.wav' -> 'emodb_16_disgust_493.wav'
# Renamed '16a07Fa.wav' -> 'emodb_16_happy_494.wav'
# Renamed '16a07Fb.wav' -> 'emodb_16_happy_495.wav'
# Deleted: ../data/raw/emodb/16a07La.wav
# Deleted: ../data/raw/emodb/16a07Lb.wav
# Renamed '16a07Nb.wav' -> 'emodb_16_neutral_498.wav'
# Renamed '16a07Td.wav' -> 'emodb_16_sad_499.wav'
# Renamed '16a07Wa.wav' -> 'emodb_16_angry_500.wav'
# Renamed '16b01Aa.wav' -> 'emodb_16_fear_501.wav'
# Renamed '16b01Eb.wav' -> 'emodb_16_disgust_502.wav'
# Renamed '16b01Fa.wav' -> 'emodb_16_happy_503.wav'
# Deleted: ../data/raw/emodb/16b01La.wav
# Deleted: ../data/raw/emodb/16b01Lc.wav
# Renamed '16b01Tb.wav' -> 'emodb_16_sad_506.wav'
# Renamed '16b01Wa.wav' -> 'emodb_16_angry_507.wav'
# Renamed '16b01Wb.wav' -> 'emodb_16_angry_508.wav'
# Renamed '16b02Aa.wav' -> 'emodb_16_fear_509.wav'
# Renamed '16b02Eb.wav' -> 'emodb_16_disgust_510.wav'
# Renamed '16b02Fd.wav' -> 'emodb_16_happy_511.wav'
# Deleted: ../data/raw/emodb/16b02Lb.wav
# Renamed '16b02Wb.wav' -> 'emodb_16_angry_513.wav'
# Renamed '16b03Ad.wav' -> 'emodb_16_fear_514.wav'
# Renamed '16b03Ea.wav' -> 'emodb_16_disgust_515.wav'
# Renamed '16b03Fa.wav' -> 'emodb_16_happy_516.wav'
# Renamed '16b03Fd.wav' -> 'emodb_16_happy_517.wav'
# Deleted: ../data/raw/emodb/16b03La.wav
# Renamed '16b03Nb.wav' -> 'emodb_16_neutral_519.wav'
# Renamed '16b03Ta.wav' -> 'emodb_16_sad_520.wav'
# Renamed '16b03Wb.wav' -> 'emodb_16_angry_521.wav'
# Renamed '16b09Ab.wav' -> 'emodb_16_fear_522.wav'
# Renamed '16b09Eb.wav' -> 'emodb_16_disgust_523.wav'
# Renamed '16b09Fb.wav' -> 'emodb_16_happy_524.wav'
# Deleted: ../data/raw/emodb/16b09La.wav
# Deleted: ../data/raw/emodb/16b09Lb.wav
# Renamed '16b09Wb.wav' -> 'emodb_16_angry_527.wav'
# Renamed '16b10Aa.wav' -> 'emodb_16_fear_528.wav'
# Renamed '16b10Eb.wav' -> 'emodb_16_disgust_529.wav'
# Renamed '16b10Fb.wav' -> 'emodb_16_happy_530.wav'
# Deleted: ../data/raw/emodb/16b10Lb.wav
# Renamed '16b10Tb.wav' -> 'emodb_16_sad_532.wav'
# Renamed '16b10Td.wav' -> 'emodb_16_sad_533.wav'
# Renamed '16b10Wa.wav' -> 'emodb_16_angry_534.wav'
# Renamed '16b10Wb.wav' -> 'emodb_16_angry_535.wav'
# Renaming completed!

# %% [markdown]
# ## Gathered Dataset

# %% [markdown]
# ### Configuration

# %%
gathered_dataset_folder_path = r"../data/raw/gathered_dataset"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
gathered_dataset_files = [f for f in os.listdir(gathered_dataset_folder_path) if f.lower().endswith('.wav')]
gathered_dataset_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(gathered_dataset_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("_", name_without_ext.lower())

    emotion_code = parts[0].lower()[1:]
    
    emotion = identify_emotion(emotion_code)
    
    actor_id = parts[0][0]
    new_name = f"gathered_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(gathered_dataset_folder_path, old_name)
    new_path = os.path.join(gathered_dataset_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")
