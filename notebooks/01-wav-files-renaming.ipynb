# %% [markdown]
# # WAV Files Renaming

# %% [markdown]
# ## Import Libraries

# %%
import os
import re
import sys
import importlib

# %% [markdown]
# ## Import Utils

# %%
sys.path.append("..")
import utils
from utils import identify_emotion

importlib.reload(utils)

from utils import identify_emotion

# %% [markdown]
# ## Crema-D Dataset

# %% [markdown]
# ### Configuration

# %%
crema_d_folder_path = r"../data/raw/crema-d"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
crema_d_wav_files = [f for f in os.listdir(crema_d_folder_path) if f.lower().endswith('.wav')]
crema_d_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(crema_d_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("_", name_without_ext)
    actor_id = parts[0]
    sentenceCode = parts[1]
    emotion_code = identify_emotion(parts[2])
    intensity_code = parts[3]
    new_name = f"crema-d_{actor_id}_{emotion_code}_{i}.wav"
    old_path = os.path.join(crema_d_folder_path, old_name)
    new_path = os.path.join(crema_d_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")

# %% [markdown]
# ## Ravdess Dataset

# %% [markdown]
# ### Configuration

# %%
ravdess_folder_path = r"../data/raw/ravdess"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
ravdess_wav_files = [f for f in os.listdir(ravdess_folder_path) if f.lower().endswith('.wav')]
ravdess_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(ravdess_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("-", name_without_ext)

    # Delete "02" and "08" files
    if parts[2] in ("02", "08"):
        old_path = os.path.join(ravdess_folder_path, old_name)
        if os.path.exists(old_path):
            os.remove(old_path)
            print(f"Deleted: {old_path}")
        continue;
    
    emotion_code = parts[2].strip()
    emotion = identify_emotion(emotion_code)
    
    actor_id = parts[6]
    new_name = f"ravdess_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(ravdess_folder_path, old_name)
    new_path = os.path.join(ravdess_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")

# %% [markdown]
# ## Savee Dataset

# %% [markdown]
# ### Configuration

# %%
savee_folder_path = r"../data/raw/savee"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
savee_wav_files = [f for f in os.listdir(savee_folder_path) if f.lower().endswith('.wav')]
savee_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(savee_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("_", name_without_ext)

    second_part = parts[1]
    emotion_code = ''.join(filter(str.isalpha, second_part))

    if emotion_code == "su":
        old_path = os.path.join(savee_folder_path, old_name)
        if os.path.exists(old_path):
            os.remove(old_path)
            print(f"Deleted: {old_path}")
        continue;
    
    emotion = identify_emotion(emotion_code)
    
    actor_id = parts[0]
    new_name = f"savee_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(savee_folder_path, old_name)
    new_path = os.path.join(savee_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")

# %% [markdown]
# ## Tess Dataset

# %% [markdown]
# ### Configuration

# %%
tess_folder_path = r"../data/raw/tess"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
tess_wav_files = [f for f in os.listdir(tess_folder_path) if f.lower().endswith('.wav')]
tess_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(tess_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("_", name_without_ext)

    emotion_code = parts[2]
    emotion = identify_emotion(emotion_code)
    
    actor_id = parts[0]
    new_name = f"savee_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(tess_folder_path, old_name)
    new_path = os.path.join(tess_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")

# %% [markdown]
# ## Subesco Dataset

# %% [markdown]
# ### Configuration

# %% [markdown]
# subesco_folder_path = r"../data/raw/subesco"
# start_number = 1
# number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
subesco_wav_files = [f for f in os.listdir(subesco_folder_path) if f.lower().endswith('.wav')]
subesco_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(subesco_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("_", name_without_ext.lower())

    emotion_code = parts[5]

    if emotion_code == "surprise":
        old_path = os.path.join(subesco_folder_path, old_name)
        if os.path.exists(old_path):
            os.remove(old_path)
            print(f"Deleted: {old_path}")
        continue;
    
    emotion = identify_emotion(emotion_code)
    
    actor_id = parts[0]
    new_name = f"subesco_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(subesco_folder_path, old_name)
    new_path = os.path.join(subesco_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")

# %% [markdown]
# ## Evomo Dataset

# %% [markdown]
# ### Configuration

# %%
emovo_folder_path = r"../data/raw/emovo"
start_number = 1
number_padding = 4

# %% [markdown]
# ### List all WAVs in the folder

# %%
emovo_wav_files = [f for f in os.listdir(emovo_folder_path) if f.lower().endswith('.wav')]
emovo_wav_files.sort()

# %% [markdown]
# ### Rename WAV Files

# %%
for i, old_name in enumerate(emovo_wav_files, start=start_number):
    name_without_ext = os.path.splitext(old_name)[0]
    parts = re.split("-", name_without_ext.lower())

    emotion_code = parts[0]

    if emotion_code == "sor":
        old_path = os.path.join(emovo_folder_path, old_name)
        if os.path.exists(old_path):
            os.remove(old_path)
            print(f"Deleted: {old_path}")
        continue;
    
    emotion = identify_emotion(emotion_code)
    
    actor_id = parts[1]
    new_name = f"emovo_{actor_id}_{emotion}_{i}.wav"
    old_path = os.path.join(emovo_folder_path, old_name)
    new_path = os.path.join(emovo_folder_path, new_name)
    os.rename(old_path, new_path)
    print(f"Renamed '{old_name}' -> '{new_name}'")

print("Renaming completed!")
# Out:
# Renamed 'dis-f1-b1.wav' -> 'emovo_f1_disgust_1.wav'
# Renamed 'dis-f1-b2.wav' -> 'emovo_f1_disgust_2.wav'
# Renamed 'dis-f1-b3.wav' -> 'emovo_f1_disgust_3.wav'
# Renamed 'dis-f1-d1.wav' -> 'emovo_f1_disgust_4.wav'
# Renamed 'dis-f1-d2.wav' -> 'emovo_f1_disgust_5.wav'
# Renamed 'dis-f1-l1.wav' -> 'emovo_f1_disgust_6.wav'
# Renamed 'dis-f1-l2.wav' -> 'emovo_f1_disgust_7.wav'
# Renamed 'dis-f1-l3.wav' -> 'emovo_f1_disgust_8.wav'
# Renamed 'dis-f1-l4.wav' -> 'emovo_f1_disgust_9.wav'
# Renamed 'dis-f1-n1.wav' -> 'emovo_f1_disgust_10.wav'
# Renamed 'dis-f1-n2.wav' -> 'emovo_f1_disgust_11.wav'
# Renamed 'dis-f1-n3.wav' -> 'emovo_f1_disgust_12.wav'
# Renamed 'dis-f1-n4.wav' -> 'emovo_f1_disgust_13.wav'
# Renamed 'dis-f1-n5.wav' -> 'emovo_f1_disgust_14.wav'
# Renamed 'dis-f2-b1.wav' -> 'emovo_f2_disgust_15.wav'
# Renamed 'dis-f2-b2.wav' -> 'emovo_f2_disgust_16.wav'
# Renamed 'dis-f2-b3.wav' -> 'emovo_f2_disgust_17.wav'
# Renamed 'dis-f2-d1.wav' -> 'emovo_f2_disgust_18.wav'
# Renamed 'dis-f2-d2.wav' -> 'emovo_f2_disgust_19.wav'
# Renamed 'dis-f2-l1.wav' -> 'emovo_f2_disgust_20.wav'
# Renamed 'dis-f2-l2.wav' -> 'emovo_f2_disgust_21.wav'
# Renamed 'dis-f2-l3.wav' -> 'emovo_f2_disgust_22.wav'
# Renamed 'dis-f2-l4.wav' -> 'emovo_f2_disgust_23.wav'
# Renamed 'dis-f2-n1.wav' -> 'emovo_f2_disgust_24.wav'
# Renamed 'dis-f2-n2.wav' -> 'emovo_f2_disgust_25.wav'
# Renamed 'dis-f2-n3.wav' -> 'emovo_f2_disgust_26.wav'
# Renamed 'dis-f2-n4.wav' -> 'emovo_f2_disgust_27.wav'
# Renamed 'dis-f2-n5.wav' -> 'emovo_f2_disgust_28.wav'
# Renamed 'dis-f3-b1.wav' -> 'emovo_f3_disgust_29.wav'
# Renamed 'dis-f3-b2.wav' -> 'emovo_f3_disgust_30.wav'
# Renamed 'dis-f3-b3.wav' -> 'emovo_f3_disgust_31.wav'
# Renamed 'dis-f3-d1.wav' -> 'emovo_f3_disgust_32.wav'
# Renamed 'dis-f3-d2.wav' -> 'emovo_f3_disgust_33.wav'
# Renamed 'dis-f3-l1.wav' -> 'emovo_f3_disgust_34.wav'
# Renamed 'dis-f3-l2.wav' -> 'emovo_f3_disgust_35.wav'
# Renamed 'dis-f3-l3.wav' -> 'emovo_f3_disgust_36.wav'
# Renamed 'dis-f3-l4.wav' -> 'emovo_f3_disgust_37.wav'
# Renamed 'dis-f3-n1.wav' -> 'emovo_f3_disgust_38.wav'
# Renamed 'dis-f3-n2.wav' -> 'emovo_f3_disgust_39.wav'
# Renamed 'dis-f3-n3.wav' -> 'emovo_f3_disgust_40.wav'
# Renamed 'dis-f3-n4.wav' -> 'emovo_f3_disgust_41.wav'
# Renamed 'dis-f3-n5.wav' -> 'emovo_f3_disgust_42.wav'
# Renamed 'dis-m1-b1.wav' -> 'emovo_m1_disgust_43.wav'
# Renamed 'dis-m1-b2.wav' -> 'emovo_m1_disgust_44.wav'
# Renamed 'dis-m1-b3.wav' -> 'emovo_m1_disgust_45.wav'
# Renamed 'dis-m1-d1.wav' -> 'emovo_m1_disgust_46.wav'
# Renamed 'dis-m1-d2.wav' -> 'emovo_m1_disgust_47.wav'
# Renamed 'dis-m1-l1.wav' -> 'emovo_m1_disgust_48.wav'
# Renamed 'dis-m1-l2.wav' -> 'emovo_m1_disgust_49.wav'
# Renamed 'dis-m1-l3.wav' -> 'emovo_m1_disgust_50.wav'
# Renamed 'dis-m1-l4.wav' -> 'emovo_m1_disgust_51.wav'
# Renamed 'dis-m1-n1.wav' -> 'emovo_m1_disgust_52.wav'
# Renamed 'dis-m1-n2.wav' -> 'emovo_m1_disgust_53.wav'
# Renamed 'dis-m1-n3.wav' -> 'emovo_m1_disgust_54.wav'
# Renamed 'dis-m1-n4.wav' -> 'emovo_m1_disgust_55.wav'
# Renamed 'dis-m1-n5.wav' -> 'emovo_m1_disgust_56.wav'
# Renamed 'dis-m2-b1.wav' -> 'emovo_m2_disgust_57.wav'
# Renamed 'dis-m2-b2.wav' -> 'emovo_m2_disgust_58.wav'
# Renamed 'dis-m2-b3.wav' -> 'emovo_m2_disgust_59.wav'
# Renamed 'dis-m2-d1.wav' -> 'emovo_m2_disgust_60.wav'
# Renamed 'dis-m2-d2.wav' -> 'emovo_m2_disgust_61.wav'
# Renamed 'dis-m2-l1.wav' -> 'emovo_m2_disgust_62.wav'
# Renamed 'dis-m2-l2.wav' -> 'emovo_m2_disgust_63.wav'
# Renamed 'dis-m2-l3.wav' -> 'emovo_m2_disgust_64.wav'
# Renamed 'dis-m2-l4.wav' -> 'emovo_m2_disgust_65.wav'
# Renamed 'dis-m2-n1.wav' -> 'emovo_m2_disgust_66.wav'
# Renamed 'dis-m2-n2.wav' -> 'emovo_m2_disgust_67.wav'
# Renamed 'dis-m2-n3.wav' -> 'emovo_m2_disgust_68.wav'
# Renamed 'dis-m2-n4.wav' -> 'emovo_m2_disgust_69.wav'
# Renamed 'dis-m2-n5.wav' -> 'emovo_m2_disgust_70.wav'
# Renamed 'dis-m3-b1.wav' -> 'emovo_m3_disgust_71.wav'
# Renamed 'dis-m3-b2.wav' -> 'emovo_m3_disgust_72.wav'
# Renamed 'dis-m3-b3.wav' -> 'emovo_m3_disgust_73.wav'
# Renamed 'dis-m3-d1.wav' -> 'emovo_m3_disgust_74.wav'
# Renamed 'dis-m3-d2.wav' -> 'emovo_m3_disgust_75.wav'
# Renamed 'dis-m3-l1.wav' -> 'emovo_m3_disgust_76.wav'
# Renamed 'dis-m3-l2.wav' -> 'emovo_m3_disgust_77.wav'
# Renamed 'dis-m3-l3.wav' -> 'emovo_m3_disgust_78.wav'
# Renamed 'dis-m3-l4.wav' -> 'emovo_m3_disgust_79.wav'
# Renamed 'dis-m3-n1.wav' -> 'emovo_m3_disgust_80.wav'
# Renamed 'dis-m3-n2.wav' -> 'emovo_m3_disgust_81.wav'
# Renamed 'dis-m3-n3.wav' -> 'emovo_m3_disgust_82.wav'
# Renamed 'dis-m3-n4.wav' -> 'emovo_m3_disgust_83.wav'
# Renamed 'dis-m3-n5.wav' -> 'emovo_m3_disgust_84.wav'
# Renamed 'gio-f1-b1.wav' -> 'emovo_f1_happy_85.wav'
# Renamed 'gio-f1-b2.wav' -> 'emovo_f1_happy_86.wav'
# Renamed 'gio-f1-b3.wav' -> 'emovo_f1_happy_87.wav'
# Renamed 'gio-f1-d1.wav' -> 'emovo_f1_happy_88.wav'
# Renamed 'gio-f1-d2.wav' -> 'emovo_f1_happy_89.wav'
# Renamed 'gio-f1-l1.wav' -> 'emovo_f1_happy_90.wav'
# Renamed 'gio-f1-l2.wav' -> 'emovo_f1_happy_91.wav'
# Renamed 'gio-f1-l3.wav' -> 'emovo_f1_happy_92.wav'
# Renamed 'gio-f1-l4.wav' -> 'emovo_f1_happy_93.wav'
# Renamed 'gio-f1-n1.wav' -> 'emovo_f1_happy_94.wav'
# Renamed 'gio-f1-n2.wav' -> 'emovo_f1_happy_95.wav'
# Renamed 'gio-f1-n3.wav' -> 'emovo_f1_happy_96.wav'
# Renamed 'gio-f1-n4.wav' -> 'emovo_f1_happy_97.wav'
# Renamed 'gio-f1-n5.wav' -> 'emovo_f1_happy_98.wav'
# Renamed 'gio-f2-b1.wav' -> 'emovo_f2_happy_99.wav'
# Renamed 'gio-f2-b2.wav' -> 'emovo_f2_happy_100.wav'
# Renamed 'gio-f2-b3.wav' -> 'emovo_f2_happy_101.wav'
# Renamed 'gio-f2-d1.wav' -> 'emovo_f2_happy_102.wav'
# Renamed 'gio-f2-d2.wav' -> 'emovo_f2_happy_103.wav'
# Renamed 'gio-f2-l1.wav' -> 'emovo_f2_happy_104.wav'
# Renamed 'gio-f2-l2.wav' -> 'emovo_f2_happy_105.wav'
# Renamed 'gio-f2-l3.wav' -> 'emovo_f2_happy_106.wav'
# Renamed 'gio-f2-l4.wav' -> 'emovo_f2_happy_107.wav'
# Renamed 'gio-f2-n1.wav' -> 'emovo_f2_happy_108.wav'
# Renamed 'gio-f2-n2.wav' -> 'emovo_f2_happy_109.wav'
# Renamed 'gio-f2-n3.wav' -> 'emovo_f2_happy_110.wav'
# Renamed 'gio-f2-n4.wav' -> 'emovo_f2_happy_111.wav'
# Renamed 'gio-f2-n5.wav' -> 'emovo_f2_happy_112.wav'
# Renamed 'gio-f3-b1.wav' -> 'emovo_f3_happy_113.wav'
# Renamed 'gio-f3-b2.wav' -> 'emovo_f3_happy_114.wav'
# Renamed 'gio-f3-b3.wav' -> 'emovo_f3_happy_115.wav'
# Renamed 'gio-f3-d1.wav' -> 'emovo_f3_happy_116.wav'
# Renamed 'gio-f3-d2.wav' -> 'emovo_f3_happy_117.wav'
# Renamed 'gio-f3-l1.wav' -> 'emovo_f3_happy_118.wav'
# Renamed 'gio-f3-l2.wav' -> 'emovo_f3_happy_119.wav'
# Renamed 'gio-f3-l3.wav' -> 'emovo_f3_happy_120.wav'
# Renamed 'gio-f3-l4.wav' -> 'emovo_f3_happy_121.wav'
# Renamed 'gio-f3-n1.wav' -> 'emovo_f3_happy_122.wav'
# Renamed 'gio-f3-n2.wav' -> 'emovo_f3_happy_123.wav'
# Renamed 'gio-f3-n3.wav' -> 'emovo_f3_happy_124.wav'
# Renamed 'gio-f3-n4.wav' -> 'emovo_f3_happy_125.wav'
# Renamed 'gio-f3-n5.wav' -> 'emovo_f3_happy_126.wav'
# Renamed 'gio-m1-b1.wav' -> 'emovo_m1_happy_127.wav'
# Renamed 'gio-m1-b2.wav' -> 'emovo_m1_happy_128.wav'
# Renamed 'gio-m1-b3.wav' -> 'emovo_m1_happy_129.wav'
# Renamed 'gio-m1-d1.wav' -> 'emovo_m1_happy_130.wav'
# Renamed 'gio-m1-d2.wav' -> 'emovo_m1_happy_131.wav'
# Renamed 'gio-m1-l1.wav' -> 'emovo_m1_happy_132.wav'
# Renamed 'gio-m1-l2.wav' -> 'emovo_m1_happy_133.wav'
# Renamed 'gio-m1-l3.wav' -> 'emovo_m1_happy_134.wav'
# Renamed 'gio-m1-l4.wav' -> 'emovo_m1_happy_135.wav'
# Renamed 'gio-m1-n1.wav' -> 'emovo_m1_happy_136.wav'
# Renamed 'gio-m1-n2.wav' -> 'emovo_m1_happy_137.wav'
# Renamed 'gio-m1-n3.wav' -> 'emovo_m1_happy_138.wav'
# Renamed 'gio-m1-n4.wav' -> 'emovo_m1_happy_139.wav'
# Renamed 'gio-m1-n5.wav' -> 'emovo_m1_happy_140.wav'
# Renamed 'gio-m2-b1.wav' -> 'emovo_m2_happy_141.wav'
# Renamed 'gio-m2-b2.wav' -> 'emovo_m2_happy_142.wav'
# Renamed 'gio-m2-b3.wav' -> 'emovo_m2_happy_143.wav'
# Renamed 'gio-m2-d1.wav' -> 'emovo_m2_happy_144.wav'
# Renamed 'gio-m2-d2.wav' -> 'emovo_m2_happy_145.wav'
# Renamed 'gio-m2-l1.wav' -> 'emovo_m2_happy_146.wav'
# Renamed 'gio-m2-l2.wav' -> 'emovo_m2_happy_147.wav'
# Renamed 'gio-m2-l3.wav' -> 'emovo_m2_happy_148.wav'
# Renamed 'gio-m2-l4.wav' -> 'emovo_m2_happy_149.wav'
# Renamed 'gio-m2-n1.wav' -> 'emovo_m2_happy_150.wav'
# Renamed 'gio-m2-n2.wav' -> 'emovo_m2_happy_151.wav'
# Renamed 'gio-m2-n3.wav' -> 'emovo_m2_happy_152.wav'
# Renamed 'gio-m2-n4.wav' -> 'emovo_m2_happy_153.wav'
# Renamed 'gio-m2-n5.wav' -> 'emovo_m2_happy_154.wav'
# Renamed 'gio-m3-b1.wav' -> 'emovo_m3_happy_155.wav'
# Renamed 'gio-m3-b2.wav' -> 'emovo_m3_happy_156.wav'
# Renamed 'gio-m3-b3.wav' -> 'emovo_m3_happy_157.wav'
# Renamed 'gio-m3-d1.wav' -> 'emovo_m3_happy_158.wav'
# Renamed 'gio-m3-d2.wav' -> 'emovo_m3_happy_159.wav'
# Renamed 'gio-m3-l1.wav' -> 'emovo_m3_happy_160.wav'
# Renamed 'gio-m3-l2.wav' -> 'emovo_m3_happy_161.wav'
# Renamed 'gio-m3-l3.wav' -> 'emovo_m3_happy_162.wav'
# Renamed 'gio-m3-l4.wav' -> 'emovo_m3_happy_163.wav'
# Renamed 'gio-m3-n1.wav' -> 'emovo_m3_happy_164.wav'
# Renamed 'gio-m3-n2.wav' -> 'emovo_m3_happy_165.wav'
# Renamed 'gio-m3-n3.wav' -> 'emovo_m3_happy_166.wav'
# Renamed 'gio-m3-n4.wav' -> 'emovo_m3_happy_167.wav'
# Renamed 'gio-m3-n5.wav' -> 'emovo_m3_happy_168.wav'
# Renamed 'neu-f1-b1.wav' -> 'emovo_f1_neutral_169.wav'
# Renamed 'neu-f1-b2.wav' -> 'emovo_f1_neutral_170.wav'
# Renamed 'neu-f1-b3.wav' -> 'emovo_f1_neutral_171.wav'
# Renamed 'neu-f1-d1.wav' -> 'emovo_f1_neutral_172.wav'
# Renamed 'neu-f1-d2.wav' -> 'emovo_f1_neutral_173.wav'
# Renamed 'neu-f1-l1.wav' -> 'emovo_f1_neutral_174.wav'
# Renamed 'neu-f1-l2.wav' -> 'emovo_f1_neutral_175.wav'
# Renamed 'neu-f1-l3.wav' -> 'emovo_f1_neutral_176.wav'
# Renamed 'neu-f1-l4.wav' -> 'emovo_f1_neutral_177.wav'
# Renamed 'neu-f1-n1.wav' -> 'emovo_f1_neutral_178.wav'
# Renamed 'neu-f1-n2.wav' -> 'emovo_f1_neutral_179.wav'
# Renamed 'neu-f1-n3.wav' -> 'emovo_f1_neutral_180.wav'
# Renamed 'neu-f1-n4.wav' -> 'emovo_f1_neutral_181.wav'
# Renamed 'neu-f1-n5.wav' -> 'emovo_f1_neutral_182.wav'
# Renamed 'neu-f2-b1.wav' -> 'emovo_f2_neutral_183.wav'
# Renamed 'neu-f2-b2.wav' -> 'emovo_f2_neutral_184.wav'
# Renamed 'neu-f2-b3.wav' -> 'emovo_f2_neutral_185.wav'
# Renamed 'neu-f2-d1.wav' -> 'emovo_f2_neutral_186.wav'
# Renamed 'neu-f2-d2.wav' -> 'emovo_f2_neutral_187.wav'
# Renamed 'neu-f2-l1.wav' -> 'emovo_f2_neutral_188.wav'
# Renamed 'neu-f2-l2.wav' -> 'emovo_f2_neutral_189.wav'
# Renamed 'neu-f2-l3.wav' -> 'emovo_f2_neutral_190.wav'
# Renamed 'neu-f2-l4.wav' -> 'emovo_f2_neutral_191.wav'
# Renamed 'neu-f2-n1.wav' -> 'emovo_f2_neutral_192.wav'
# Renamed 'neu-f2-n2.wav' -> 'emovo_f2_neutral_193.wav'
# Renamed 'neu-f2-n3.wav' -> 'emovo_f2_neutral_194.wav'
# Renamed 'neu-f2-n4.wav' -> 'emovo_f2_neutral_195.wav'
# Renamed 'neu-f2-n5.wav' -> 'emovo_f2_neutral_196.wav'
# Renamed 'neu-f3-b1.wav' -> 'emovo_f3_neutral_197.wav'
# Renamed 'neu-f3-b2.wav' -> 'emovo_f3_neutral_198.wav'
# Renamed 'neu-f3-b3.wav' -> 'emovo_f3_neutral_199.wav'
# Renamed 'neu-f3-d1.wav' -> 'emovo_f3_neutral_200.wav'
# Renamed 'neu-f3-d2.wav' -> 'emovo_f3_neutral_201.wav'
# Renamed 'neu-f3-l1.wav' -> 'emovo_f3_neutral_202.wav'
# Renamed 'neu-f3-l2.wav' -> 'emovo_f3_neutral_203.wav'
# Renamed 'neu-f3-l3.wav' -> 'emovo_f3_neutral_204.wav'
# Renamed 'neu-f3-l4.wav' -> 'emovo_f3_neutral_205.wav'
# Renamed 'neu-f3-n1.wav' -> 'emovo_f3_neutral_206.wav'
# Renamed 'neu-f3-n2.wav' -> 'emovo_f3_neutral_207.wav'
# Renamed 'neu-f3-n3.wav' -> 'emovo_f3_neutral_208.wav'
# Renamed 'neu-f3-n4.wav' -> 'emovo_f3_neutral_209.wav'
# Renamed 'neu-f3-n5.wav' -> 'emovo_f3_neutral_210.wav'
# Renamed 'neu-m1-b1.wav' -> 'emovo_m1_neutral_211.wav'
# Renamed 'neu-m1-b2.wav' -> 'emovo_m1_neutral_212.wav'
# Renamed 'neu-m1-b3.wav' -> 'emovo_m1_neutral_213.wav'
# Renamed 'neu-m1-d1.wav' -> 'emovo_m1_neutral_214.wav'
# Renamed 'neu-m1-d2.wav' -> 'emovo_m1_neutral_215.wav'
# Renamed 'neu-m1-l1.wav' -> 'emovo_m1_neutral_216.wav'
# Renamed 'neu-m1-l2.wav' -> 'emovo_m1_neutral_217.wav'
# Renamed 'neu-m1-l3.wav' -> 'emovo_m1_neutral_218.wav'
# Renamed 'neu-m1-l4.wav' -> 'emovo_m1_neutral_219.wav'
# Renamed 'neu-m1-n1.wav' -> 'emovo_m1_neutral_220.wav'
# Renamed 'neu-m1-n2.wav' -> 'emovo_m1_neutral_221.wav'
# Renamed 'neu-m1-n3.wav' -> 'emovo_m1_neutral_222.wav'
# Renamed 'neu-m1-n4.wav' -> 'emovo_m1_neutral_223.wav'
# Renamed 'neu-m1-n5.wav' -> 'emovo_m1_neutral_224.wav'
# Renamed 'neu-m2-b1.wav' -> 'emovo_m2_neutral_225.wav'
# Renamed 'neu-m2-b2.wav' -> 'emovo_m2_neutral_226.wav'
# Renamed 'neu-m2-b3.wav' -> 'emovo_m2_neutral_227.wav'
# Renamed 'neu-m2-d1.wav' -> 'emovo_m2_neutral_228.wav'
# Renamed 'neu-m2-d2.wav' -> 'emovo_m2_neutral_229.wav'
# Renamed 'neu-m2-l1.wav' -> 'emovo_m2_neutral_230.wav'
# Renamed 'neu-m2-l2.wav' -> 'emovo_m2_neutral_231.wav'
# Renamed 'neu-m2-l3.wav' -> 'emovo_m2_neutral_232.wav'
# Renamed 'neu-m2-l4.wav' -> 'emovo_m2_neutral_233.wav'
# Renamed 'neu-m2-n1.wav' -> 'emovo_m2_neutral_234.wav'
# Renamed 'neu-m2-n2.wav' -> 'emovo_m2_neutral_235.wav'
# Renamed 'neu-m2-n3.wav' -> 'emovo_m2_neutral_236.wav'
# Renamed 'neu-m2-n4.wav' -> 'emovo_m2_neutral_237.wav'
# Renamed 'neu-m2-n5.wav' -> 'emovo_m2_neutral_238.wav'
# Renamed 'neu-m3-b1.wav' -> 'emovo_m3_neutral_239.wav'
# Renamed 'neu-m3-b2.wav' -> 'emovo_m3_neutral_240.wav'
# Renamed 'neu-m3-b3.wav' -> 'emovo_m3_neutral_241.wav'
# Renamed 'neu-m3-d1.wav' -> 'emovo_m3_neutral_242.wav'
# Renamed 'neu-m3-d2.wav' -> 'emovo_m3_neutral_243.wav'
# Renamed 'neu-m3-l1.wav' -> 'emovo_m3_neutral_244.wav'
# Renamed 'neu-m3-l2.wav' -> 'emovo_m3_neutral_245.wav'
# Renamed 'neu-m3-l3.wav' -> 'emovo_m3_neutral_246.wav'
# Renamed 'neu-m3-l4.wav' -> 'emovo_m3_neutral_247.wav'
# Renamed 'neu-m3-n1.wav' -> 'emovo_m3_neutral_248.wav'
# Renamed 'neu-m3-n2.wav' -> 'emovo_m3_neutral_249.wav'
# Renamed 'neu-m3-n3.wav' -> 'emovo_m3_neutral_250.wav'
# Renamed 'neu-m3-n4.wav' -> 'emovo_m3_neutral_251.wav'
# Renamed 'neu-m3-n5.wav' -> 'emovo_m3_neutral_252.wav'
# Renamed 'pau-f1-b1.wav' -> 'emovo_f1_fear_253.wav'
# Renamed 'pau-f1-b2.wav' -> 'emovo_f1_fear_254.wav'
# Renamed 'pau-f1-b3.wav' -> 'emovo_f1_fear_255.wav'
# Renamed 'pau-f1-d1.wav' -> 'emovo_f1_fear_256.wav'
# Renamed 'pau-f1-d2.wav' -> 'emovo_f1_fear_257.wav'
# Renamed 'pau-f1-l1.wav' -> 'emovo_f1_fear_258.wav'
# Renamed 'pau-f1-l2.wav' -> 'emovo_f1_fear_259.wav'
# Renamed 'pau-f1-l3.wav' -> 'emovo_f1_fear_260.wav'
# Renamed 'pau-f1-l4.wav' -> 'emovo_f1_fear_261.wav'
# Renamed 'pau-f1-n1.wav' -> 'emovo_f1_fear_262.wav'
# Renamed 'pau-f1-n2.wav' -> 'emovo_f1_fear_263.wav'
# Renamed 'pau-f1-n3.wav' -> 'emovo_f1_fear_264.wav'
# Renamed 'pau-f1-n4.wav' -> 'emovo_f1_fear_265.wav'
# Renamed 'pau-f1-n5.wav' -> 'emovo_f1_fear_266.wav'
# Renamed 'pau-f2-b1.wav' -> 'emovo_f2_fear_267.wav'
# Renamed 'pau-f2-b2.wav' -> 'emovo_f2_fear_268.wav'
# Renamed 'pau-f2-b3.wav' -> 'emovo_f2_fear_269.wav'
# Renamed 'pau-f2-d1.wav' -> 'emovo_f2_fear_270.wav'
# Renamed 'pau-f2-d2.wav' -> 'emovo_f2_fear_271.wav'
# Renamed 'pau-f2-l1.wav' -> 'emovo_f2_fear_272.wav'
# Renamed 'pau-f2-l2.wav' -> 'emovo_f2_fear_273.wav'
# Renamed 'pau-f2-l3.wav' -> 'emovo_f2_fear_274.wav'
# Renamed 'pau-f2-l4.wav' -> 'emovo_f2_fear_275.wav'
# Renamed 'pau-f2-n1.wav' -> 'emovo_f2_fear_276.wav'
# Renamed 'pau-f2-n2.wav' -> 'emovo_f2_fear_277.wav'
# Renamed 'pau-f2-n3.wav' -> 'emovo_f2_fear_278.wav'
# Renamed 'pau-f2-n4.wav' -> 'emovo_f2_fear_279.wav'
# Renamed 'pau-f2-n5.wav' -> 'emovo_f2_fear_280.wav'
# Renamed 'pau-f3-b1.wav' -> 'emovo_f3_fear_281.wav'
# Renamed 'pau-f3-b2.wav' -> 'emovo_f3_fear_282.wav'
# Renamed 'pau-f3-b3.wav' -> 'emovo_f3_fear_283.wav'
# Renamed 'pau-f3-d1.wav' -> 'emovo_f3_fear_284.wav'
# Renamed 'pau-f3-d2.wav' -> 'emovo_f3_fear_285.wav'
# Renamed 'pau-f3-l1.wav' -> 'emovo_f3_fear_286.wav'
# Renamed 'pau-f3-l2.wav' -> 'emovo_f3_fear_287.wav'
# Renamed 'pau-f3-l3.wav' -> 'emovo_f3_fear_288.wav'
# Renamed 'pau-f3-l4.wav' -> 'emovo_f3_fear_289.wav'
# Renamed 'pau-f3-n1.wav' -> 'emovo_f3_fear_290.wav'
# Renamed 'pau-f3-n2.wav' -> 'emovo_f3_fear_291.wav'
# Renamed 'pau-f3-n3.wav' -> 'emovo_f3_fear_292.wav'
# Renamed 'pau-f3-n4.wav' -> 'emovo_f3_fear_293.wav'
# Renamed 'pau-f3-n5.wav' -> 'emovo_f3_fear_294.wav'
# Renamed 'pau-m1-b1.wav' -> 'emovo_m1_fear_295.wav'
# Renamed 'pau-m1-b2.wav' -> 'emovo_m1_fear_296.wav'
# Renamed 'pau-m1-b3.wav' -> 'emovo_m1_fear_297.wav'
# Renamed 'pau-m1-d1.wav' -> 'emovo_m1_fear_298.wav'
# Renamed 'pau-m1-d2.wav' -> 'emovo_m1_fear_299.wav'
# Renamed 'pau-m1-l1.wav' -> 'emovo_m1_fear_300.wav'
# Renamed 'pau-m1-l2.wav' -> 'emovo_m1_fear_301.wav'
# Renamed 'pau-m1-l3.wav' -> 'emovo_m1_fear_302.wav'
# Renamed 'pau-m1-l4.wav' -> 'emovo_m1_fear_303.wav'
# Renamed 'pau-m1-n1.wav' -> 'emovo_m1_fear_304.wav'
# Renamed 'pau-m1-n2.wav' -> 'emovo_m1_fear_305.wav'
# Renamed 'pau-m1-n3.wav' -> 'emovo_m1_fear_306.wav'
# Renamed 'pau-m1-n4.wav' -> 'emovo_m1_fear_307.wav'
# Renamed 'pau-m1-n5.wav' -> 'emovo_m1_fear_308.wav'
# Renamed 'pau-m2-b1.wav' -> 'emovo_m2_fear_309.wav'
# Renamed 'pau-m2-b2.wav' -> 'emovo_m2_fear_310.wav'
# Renamed 'pau-m2-b3.wav' -> 'emovo_m2_fear_311.wav'
# Renamed 'pau-m2-d1.wav' -> 'emovo_m2_fear_312.wav'
# Renamed 'pau-m2-d2.wav' -> 'emovo_m2_fear_313.wav'
# Renamed 'pau-m2-l1.wav' -> 'emovo_m2_fear_314.wav'
# Renamed 'pau-m2-l2.wav' -> 'emovo_m2_fear_315.wav'
# Renamed 'pau-m2-l3.wav' -> 'emovo_m2_fear_316.wav'
# Renamed 'pau-m2-l4.wav' -> 'emovo_m2_fear_317.wav'
# Renamed 'pau-m2-n1.wav' -> 'emovo_m2_fear_318.wav'
# Renamed 'pau-m2-n2.wav' -> 'emovo_m2_fear_319.wav'
# Renamed 'pau-m2-n3.wav' -> 'emovo_m2_fear_320.wav'
# Renamed 'pau-m2-n4.wav' -> 'emovo_m2_fear_321.wav'
# Renamed 'pau-m2-n5.wav' -> 'emovo_m2_fear_322.wav'
# Renamed 'pau-m3-b1.wav' -> 'emovo_m3_fear_323.wav'
# Renamed 'pau-m3-b2.wav' -> 'emovo_m3_fear_324.wav'
# Renamed 'pau-m3-b3.wav' -> 'emovo_m3_fear_325.wav'
# Renamed 'pau-m3-d1.wav' -> 'emovo_m3_fear_326.wav'
# Renamed 'pau-m3-d2.wav' -> 'emovo_m3_fear_327.wav'
# Renamed 'pau-m3-l1.wav' -> 'emovo_m3_fear_328.wav'
# Renamed 'pau-m3-l2.wav' -> 'emovo_m3_fear_329.wav'
# Renamed 'pau-m3-l3.wav' -> 'emovo_m3_fear_330.wav'
# Renamed 'pau-m3-l4.wav' -> 'emovo_m3_fear_331.wav'
# Renamed 'pau-m3-n1.wav' -> 'emovo_m3_fear_332.wav'
# Renamed 'pau-m3-n2.wav' -> 'emovo_m3_fear_333.wav'
# Renamed 'pau-m3-n3.wav' -> 'emovo_m3_fear_334.wav'
# Renamed 'pau-m3-n4.wav' -> 'emovo_m3_fear_335.wav'
# Renamed 'pau-m3-n5.wav' -> 'emovo_m3_fear_336.wav'
# Renamed 'rab-f1-b1.wav' -> 'emovo_f1_angry_337.wav'
# Renamed 'rab-f1-b2.wav' -> 'emovo_f1_angry_338.wav'
# Renamed 'rab-f1-b3.wav' -> 'emovo_f1_angry_339.wav'
# Renamed 'rab-f1-d1.wav' -> 'emovo_f1_angry_340.wav'
# Renamed 'rab-f1-d2.wav' -> 'emovo_f1_angry_341.wav'
# Renamed 'rab-f1-l1.wav' -> 'emovo_f1_angry_342.wav'
# Renamed 'rab-f1-l2.wav' -> 'emovo_f1_angry_343.wav'
# Renamed 'rab-f1-l3.wav' -> 'emovo_f1_angry_344.wav'
# Renamed 'rab-f1-l4.wav' -> 'emovo_f1_angry_345.wav'
# Renamed 'rab-f1-n1.wav' -> 'emovo_f1_angry_346.wav'
# Renamed 'rab-f1-n2.wav' -> 'emovo_f1_angry_347.wav'
# Renamed 'rab-f1-n3.wav' -> 'emovo_f1_angry_348.wav'
# Renamed 'rab-f1-n4.wav' -> 'emovo_f1_angry_349.wav'
# Renamed 'rab-f1-n5.wav' -> 'emovo_f1_angry_350.wav'
# Renamed 'rab-f2-b1.wav' -> 'emovo_f2_angry_351.wav'
# Renamed 'rab-f2-b2.wav' -> 'emovo_f2_angry_352.wav'
# Renamed 'rab-f2-b3.wav' -> 'emovo_f2_angry_353.wav'
# Renamed 'rab-f2-d1.wav' -> 'emovo_f2_angry_354.wav'
# Renamed 'rab-f2-d2.wav' -> 'emovo_f2_angry_355.wav'
# Renamed 'rab-f2-l1.wav' -> 'emovo_f2_angry_356.wav'
# Renamed 'rab-f2-l2.wav' -> 'emovo_f2_angry_357.wav'
# Renamed 'rab-f2-l3.wav' -> 'emovo_f2_angry_358.wav'
# Renamed 'rab-f2-l4.wav' -> 'emovo_f2_angry_359.wav'
# Renamed 'rab-f2-n1.wav' -> 'emovo_f2_angry_360.wav'
# Renamed 'rab-f2-n2.wav' -> 'emovo_f2_angry_361.wav'
# Renamed 'rab-f2-n3.wav' -> 'emovo_f2_angry_362.wav'
# Renamed 'rab-f2-n4.wav' -> 'emovo_f2_angry_363.wav'
# Renamed 'rab-f2-n5.wav' -> 'emovo_f2_angry_364.wav'
# Renamed 'rab-f3-b1.wav' -> 'emovo_f3_angry_365.wav'
# Renamed 'rab-f3-b2.wav' -> 'emovo_f3_angry_366.wav'
# Renamed 'rab-f3-b3.wav' -> 'emovo_f3_angry_367.wav'
# Renamed 'rab-f3-d1.wav' -> 'emovo_f3_angry_368.wav'
# Renamed 'rab-f3-d2.wav' -> 'emovo_f3_angry_369.wav'
# Renamed 'rab-f3-l1.wav' -> 'emovo_f3_angry_370.wav'
# Renamed 'rab-f3-l2.wav' -> 'emovo_f3_angry_371.wav'
# Renamed 'rab-f3-l3.wav' -> 'emovo_f3_angry_372.wav'
# Renamed 'rab-f3-l4.wav' -> 'emovo_f3_angry_373.wav'
# Renamed 'rab-f3-n1.wav' -> 'emovo_f3_angry_374.wav'
# Renamed 'rab-f3-n2.wav' -> 'emovo_f3_angry_375.wav'
# Renamed 'rab-f3-n3.wav' -> 'emovo_f3_angry_376.wav'
# Renamed 'rab-f3-n4.wav' -> 'emovo_f3_angry_377.wav'
# Renamed 'rab-f3-n5.wav' -> 'emovo_f3_angry_378.wav'
# Renamed 'rab-m1-b1.wav' -> 'emovo_m1_angry_379.wav'
# Renamed 'rab-m1-b2.wav' -> 'emovo_m1_angry_380.wav'
# Renamed 'rab-m1-b3.wav' -> 'emovo_m1_angry_381.wav'
# Renamed 'rab-m1-d1.wav' -> 'emovo_m1_angry_382.wav'
# Renamed 'rab-m1-d2.wav' -> 'emovo_m1_angry_383.wav'
# Renamed 'rab-m1-l1.wav' -> 'emovo_m1_angry_384.wav'
# Renamed 'rab-m1-l2.wav' -> 'emovo_m1_angry_385.wav'
# Renamed 'rab-m1-l3.wav' -> 'emovo_m1_angry_386.wav'
# Renamed 'rab-m1-l4.wav' -> 'emovo_m1_angry_387.wav'
# Renamed 'rab-m1-n1.wav' -> 'emovo_m1_angry_388.wav'
# Renamed 'rab-m1-n2.wav' -> 'emovo_m1_angry_389.wav'
# Renamed 'rab-m1-n3.wav' -> 'emovo_m1_angry_390.wav'
# Renamed 'rab-m1-n4.wav' -> 'emovo_m1_angry_391.wav'
# Renamed 'rab-m1-n5.wav' -> 'emovo_m1_angry_392.wav'
# Renamed 'rab-m2-b1.wav' -> 'emovo_m2_angry_393.wav'
# Renamed 'rab-m2-b2.wav' -> 'emovo_m2_angry_394.wav'
# Renamed 'rab-m2-b3.wav' -> 'emovo_m2_angry_395.wav'
# Renamed 'rab-m2-d1.wav' -> 'emovo_m2_angry_396.wav'
# Renamed 'rab-m2-d2.wav' -> 'emovo_m2_angry_397.wav'
# Renamed 'rab-m2-l1.wav' -> 'emovo_m2_angry_398.wav'
# Renamed 'rab-m2-l2.wav' -> 'emovo_m2_angry_399.wav'
# Renamed 'rab-m2-l3.wav' -> 'emovo_m2_angry_400.wav'
# Renamed 'rab-m2-l4.wav' -> 'emovo_m2_angry_401.wav'
# Renamed 'rab-m2-n1.wav' -> 'emovo_m2_angry_402.wav'
# Renamed 'rab-m2-n2.wav' -> 'emovo_m2_angry_403.wav'
# Renamed 'rab-m2-n3.wav' -> 'emovo_m2_angry_404.wav'
# Renamed 'rab-m2-n4.wav' -> 'emovo_m2_angry_405.wav'
# Renamed 'rab-m2-n5.wav' -> 'emovo_m2_angry_406.wav'
# Renamed 'rab-m3-b1.wav' -> 'emovo_m3_angry_407.wav'
# Renamed 'rab-m3-b2.wav' -> 'emovo_m3_angry_408.wav'
# Renamed 'rab-m3-b3.wav' -> 'emovo_m3_angry_409.wav'
# Renamed 'rab-m3-d1.wav' -> 'emovo_m3_angry_410.wav'
# Renamed 'rab-m3-d2.wav' -> 'emovo_m3_angry_411.wav'
# Renamed 'rab-m3-l1.wav' -> 'emovo_m3_angry_412.wav'
# Renamed 'rab-m3-l2.wav' -> 'emovo_m3_angry_413.wav'
# Renamed 'rab-m3-l3.wav' -> 'emovo_m3_angry_414.wav'
# Renamed 'rab-m3-l4.wav' -> 'emovo_m3_angry_415.wav'
# Renamed 'rab-m3-n1.wav' -> 'emovo_m3_angry_416.wav'
# Renamed 'rab-m3-n2.wav' -> 'emovo_m3_angry_417.wav'
# Renamed 'rab-m3-n3.wav' -> 'emovo_m3_angry_418.wav'
# Renamed 'rab-m3-n4.wav' -> 'emovo_m3_angry_419.wav'
# Renamed 'rab-m3-n5.wav' -> 'emovo_m3_angry_420.wav'
# Deleted: ../data/raw/emovo/sor-f1-b1.wav
# Deleted: ../data/raw/emovo/sor-f1-b2.wav
# Deleted: ../data/raw/emovo/sor-f1-b3.wav
# Deleted: ../data/raw/emovo/sor-f1-d1.wav
# Deleted: ../data/raw/emovo/sor-f1-d2.wav
# Deleted: ../data/raw/emovo/sor-f1-l1.wav
# Deleted: ../data/raw/emovo/sor-f1-l2.wav
# Deleted: ../data/raw/emovo/sor-f1-l3.wav
# Deleted: ../data/raw/emovo/sor-f1-l4.wav
# Deleted: ../data/raw/emovo/sor-f1-n1.wav
# Deleted: ../data/raw/emovo/sor-f1-n2.wav
# Deleted: ../data/raw/emovo/sor-f1-n3.wav
# Deleted: ../data/raw/emovo/sor-f1-n4.wav
# Deleted: ../data/raw/emovo/sor-f1-n5.wav
# Deleted: ../data/raw/emovo/sor-f2-b1.wav
# Deleted: ../data/raw/emovo/sor-f2-b2.wav
# Deleted: ../data/raw/emovo/sor-f2-b3.wav
# Deleted: ../data/raw/emovo/sor-f2-d1.wav
# Deleted: ../data/raw/emovo/sor-f2-d2.wav
# Deleted: ../data/raw/emovo/sor-f2-l1.wav
# Deleted: ../data/raw/emovo/sor-f2-l2.wav
# Deleted: ../data/raw/emovo/sor-f2-l3.wav
# Deleted: ../data/raw/emovo/sor-f2-l4.wav
# Deleted: ../data/raw/emovo/sor-f2-n1.wav
# Deleted: ../data/raw/emovo/sor-f2-n2.wav
# Deleted: ../data/raw/emovo/sor-f2-n3.wav
# Deleted: ../data/raw/emovo/sor-f2-n4.wav
# Deleted: ../data/raw/emovo/sor-f2-n5.wav
# Deleted: ../data/raw/emovo/sor-f3-b1.wav
# Deleted: ../data/raw/emovo/sor-f3-b2.wav
# Deleted: ../data/raw/emovo/sor-f3-b3.wav
# Deleted: ../data/raw/emovo/sor-f3-d1.wav
# Deleted: ../data/raw/emovo/sor-f3-d2.wav
# Deleted: ../data/raw/emovo/sor-f3-l1.wav
# Deleted: ../data/raw/emovo/sor-f3-l2.wav
# Deleted: ../data/raw/emovo/sor-f3-l3.wav
# Deleted: ../data/raw/emovo/sor-f3-l4.wav
# Deleted: ../data/raw/emovo/sor-f3-n1.wav
# Deleted: ../data/raw/emovo/sor-f3-n2.wav
# Deleted: ../data/raw/emovo/sor-f3-n3.wav
# Deleted: ../data/raw/emovo/sor-f3-n4.wav
# Deleted: ../data/raw/emovo/sor-f3-n5.wav
# Deleted: ../data/raw/emovo/sor-m1-b1.wav
# Deleted: ../data/raw/emovo/sor-m1-b2.wav
# Deleted: ../data/raw/emovo/sor-m1-b3.wav
# Deleted: ../data/raw/emovo/sor-m1-d1.wav
# Deleted: ../data/raw/emovo/sor-m1-d2.wav
# Deleted: ../data/raw/emovo/sor-m1-l1.wav
# Deleted: ../data/raw/emovo/sor-m1-l2.wav
# Deleted: ../data/raw/emovo/sor-m1-l3.wav
# Deleted: ../data/raw/emovo/sor-m1-l4.wav
# Deleted: ../data/raw/emovo/sor-m1-n1.wav
# Deleted: ../data/raw/emovo/sor-m1-n2.wav
# Deleted: ../data/raw/emovo/sor-m1-n3.wav
# Deleted: ../data/raw/emovo/sor-m1-n4.wav
# Deleted: ../data/raw/emovo/sor-m1-n5.wav
# Deleted: ../data/raw/emovo/sor-m2-b1.wav
# Deleted: ../data/raw/emovo/sor-m2-b2.wav
# Deleted: ../data/raw/emovo/sor-m2-b3.wav
# Deleted: ../data/raw/emovo/sor-m2-d1.wav
# Deleted: ../data/raw/emovo/sor-m2-d2.wav
# Deleted: ../data/raw/emovo/sor-m2-l1.wav
# Deleted: ../data/raw/emovo/sor-m2-l2.wav
# Deleted: ../data/raw/emovo/sor-m2-l3.wav
# Deleted: ../data/raw/emovo/sor-m2-l4.wav
# Deleted: ../data/raw/emovo/sor-m2-n1.wav
# Deleted: ../data/raw/emovo/sor-m2-n2.wav
# Deleted: ../data/raw/emovo/sor-m2-n3.wav
# Deleted: ../data/raw/emovo/sor-m2-n4.wav
# Deleted: ../data/raw/emovo/sor-m2-n5.wav
# Deleted: ../data/raw/emovo/sor-m3-b1.wav
# Deleted: ../data/raw/emovo/sor-m3-b2.wav
# Deleted: ../data/raw/emovo/sor-m3-b3.wav
# Deleted: ../data/raw/emovo/sor-m3-d1.wav
# Deleted: ../data/raw/emovo/sor-m3-d2.wav
# Deleted: ../data/raw/emovo/sor-m3-l1.wav
# Deleted: ../data/raw/emovo/sor-m3-l2.wav
# Deleted: ../data/raw/emovo/sor-m3-l3.wav
# Deleted: ../data/raw/emovo/sor-m3-l4.wav
# Deleted: ../data/raw/emovo/sor-m3-n1.wav
# Deleted: ../data/raw/emovo/sor-m3-n2.wav
# Deleted: ../data/raw/emovo/sor-m3-n3.wav
# Deleted: ../data/raw/emovo/sor-m3-n4.wav
# Deleted: ../data/raw/emovo/sor-m3-n5.wav
# Renamed 'tri-f1-b1.wav' -> 'emovo_f1_sad_505.wav'
# Renamed 'tri-f1-b2.wav' -> 'emovo_f1_sad_506.wav'
# Renamed 'tri-f1-b3.wav' -> 'emovo_f1_sad_507.wav'
# Renamed 'tri-f1-d1.wav' -> 'emovo_f1_sad_508.wav'
# Renamed 'tri-f1-d2.wav' -> 'emovo_f1_sad_509.wav'
# Renamed 'tri-f1-l1.wav' -> 'emovo_f1_sad_510.wav'
# Renamed 'tri-f1-l2.wav' -> 'emovo_f1_sad_511.wav'
# Renamed 'tri-f1-l3.wav' -> 'emovo_f1_sad_512.wav'
# Renamed 'tri-f1-l4.wav' -> 'emovo_f1_sad_513.wav'
# Renamed 'tri-f1-n1.wav' -> 'emovo_f1_sad_514.wav'
# Renamed 'tri-f1-n2.wav' -> 'emovo_f1_sad_515.wav'
# Renamed 'tri-f1-n3.wav' -> 'emovo_f1_sad_516.wav'
# Renamed 'tri-f1-n4.wav' -> 'emovo_f1_sad_517.wav'
# Renamed 'tri-f1-n5.wav' -> 'emovo_f1_sad_518.wav'
# Renamed 'tri-f2-b1.wav' -> 'emovo_f2_sad_519.wav'
# Renamed 'tri-f2-b2.wav' -> 'emovo_f2_sad_520.wav'
# Renamed 'tri-f2-b3.wav' -> 'emovo_f2_sad_521.wav'
# Renamed 'tri-f2-d1.wav' -> 'emovo_f2_sad_522.wav'
# Renamed 'tri-f2-d2.wav' -> 'emovo_f2_sad_523.wav'
# Renamed 'tri-f2-l1.wav' -> 'emovo_f2_sad_524.wav'
# Renamed 'tri-f2-l2.wav' -> 'emovo_f2_sad_525.wav'
# Renamed 'tri-f2-l3.wav' -> 'emovo_f2_sad_526.wav'
# Renamed 'tri-f2-l4.wav' -> 'emovo_f2_sad_527.wav'
# Renamed 'tri-f2-n1.wav' -> 'emovo_f2_sad_528.wav'
# Renamed 'tri-f2-n2.wav' -> 'emovo_f2_sad_529.wav'
# Renamed 'tri-f2-n3.wav' -> 'emovo_f2_sad_530.wav'
# Renamed 'tri-f2-n4.wav' -> 'emovo_f2_sad_531.wav'
# Renamed 'tri-f2-n5.wav' -> 'emovo_f2_sad_532.wav'
# Renamed 'tri-f3-b1.wav' -> 'emovo_f3_sad_533.wav'
# Renamed 'tri-f3-b2.wav' -> 'emovo_f3_sad_534.wav'
# Renamed 'tri-f3-b3.wav' -> 'emovo_f3_sad_535.wav'
# Renamed 'tri-f3-d1.wav' -> 'emovo_f3_sad_536.wav'
# Renamed 'tri-f3-d2.wav' -> 'emovo_f3_sad_537.wav'
# Renamed 'tri-f3-l1.wav' -> 'emovo_f3_sad_538.wav'
# Renamed 'tri-f3-l2.wav' -> 'emovo_f3_sad_539.wav'
# Renamed 'tri-f3-l3.wav' -> 'emovo_f3_sad_540.wav'
# Renamed 'tri-f3-l4.wav' -> 'emovo_f3_sad_541.wav'
# Renamed 'tri-f3-n1.wav' -> 'emovo_f3_sad_542.wav'
# Renamed 'tri-f3-n2.wav' -> 'emovo_f3_sad_543.wav'
# Renamed 'tri-f3-n3.wav' -> 'emovo_f3_sad_544.wav'
# Renamed 'tri-f3-n4.wav' -> 'emovo_f3_sad_545.wav'
# Renamed 'tri-f3-n5.wav' -> 'emovo_f3_sad_546.wav'
# Renamed 'tri-m1-b1.wav' -> 'emovo_m1_sad_547.wav'
# Renamed 'tri-m1-b2.wav' -> 'emovo_m1_sad_548.wav'
# Renamed 'tri-m1-b3.wav' -> 'emovo_m1_sad_549.wav'
# Renamed 'tri-m1-d1.wav' -> 'emovo_m1_sad_550.wav'
# Renamed 'tri-m1-d2.wav' -> 'emovo_m1_sad_551.wav'
# Renamed 'tri-m1-l1.wav' -> 'emovo_m1_sad_552.wav'
# Renamed 'tri-m1-l2.wav' -> 'emovo_m1_sad_553.wav'
# Renamed 'tri-m1-l3.wav' -> 'emovo_m1_sad_554.wav'
# Renamed 'tri-m1-l4.wav' -> 'emovo_m1_sad_555.wav'
# Renamed 'tri-m1-n1.wav' -> 'emovo_m1_sad_556.wav'
# Renamed 'tri-m1-n2.wav' -> 'emovo_m1_sad_557.wav'
# Renamed 'tri-m1-n3.wav' -> 'emovo_m1_sad_558.wav'
# Renamed 'tri-m1-n4.wav' -> 'emovo_m1_sad_559.wav'
# Renamed 'tri-m1-n5.wav' -> 'emovo_m1_sad_560.wav'
# Renamed 'tri-m2-b1.wav' -> 'emovo_m2_sad_561.wav'
# Renamed 'tri-m2-b2.wav' -> 'emovo_m2_sad_562.wav'
# Renamed 'tri-m2-b3.wav' -> 'emovo_m2_sad_563.wav'
# Renamed 'tri-m2-d1.wav' -> 'emovo_m2_sad_564.wav'
# Renamed 'tri-m2-d2.wav' -> 'emovo_m2_sad_565.wav'
# Renamed 'tri-m2-l1.wav' -> 'emovo_m2_sad_566.wav'
# Renamed 'tri-m2-l2.wav' -> 'emovo_m2_sad_567.wav'
# Renamed 'tri-m2-l3.wav' -> 'emovo_m2_sad_568.wav'
# Renamed 'tri-m2-l4.wav' -> 'emovo_m2_sad_569.wav'
# Renamed 'tri-m2-n1.wav' -> 'emovo_m2_sad_570.wav'
# Renamed 'tri-m2-n2.wav' -> 'emovo_m2_sad_571.wav'
# Renamed 'tri-m2-n3.wav' -> 'emovo_m2_sad_572.wav'
# Renamed 'tri-m2-n4.wav' -> 'emovo_m2_sad_573.wav'
# Renamed 'tri-m2-n5.wav' -> 'emovo_m2_sad_574.wav'
# Renamed 'tri-m3-b1.wav' -> 'emovo_m3_sad_575.wav'
# Renamed 'tri-m3-b2.wav' -> 'emovo_m3_sad_576.wav'
# Renamed 'tri-m3-b3.wav' -> 'emovo_m3_sad_577.wav'
# Renamed 'tri-m3-d1.wav' -> 'emovo_m3_sad_578.wav'
# Renamed 'tri-m3-d2.wav' -> 'emovo_m3_sad_579.wav'
# Renamed 'tri-m3-l1.wav' -> 'emovo_m3_sad_580.wav'
# Renamed 'tri-m3-l2.wav' -> 'emovo_m3_sad_581.wav'
# Renamed 'tri-m3-l3.wav' -> 'emovo_m3_sad_582.wav'
# Renamed 'tri-m3-l4.wav' -> 'emovo_m3_sad_583.wav'
# Renamed 'tri-m3-n1.wav' -> 'emovo_m3_sad_584.wav'
# Renamed 'tri-m3-n2.wav' -> 'emovo_m3_sad_585.wav'
# Renamed 'tri-m3-n3.wav' -> 'emovo_m3_sad_586.wav'
# Renamed 'tri-m3-n4.wav' -> 'emovo_m3_sad_587.wav'
# Renamed 'tri-m3-n5.wav' -> 'emovo_m3_sad_588.wav'
# Renaming completed!
